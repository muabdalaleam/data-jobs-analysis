# %% [markdown]
# ## <center><strong>Notebook describtion & Our <span style= 'color: #51fcc6'>Questions</span>

# %% [markdown]
# In this notebook we are going to create the charts that we are going to use in the final pdf report and the tools we are going<br>
# to use are matplotlib and seaborn.

# %% [markdown]
# #### **Questions we are going to awnser:**
# 1. How many jobs are available per country and per profession on Likedin.
#
# 2. What's the ratio between people who earned money on UpWork Vs Guru.
#
# 3. Average salary per profession and per country on LinkedIn.
#
# 4. What's Top 5 people in earnings amount most frequent words in thier describtions.<sub> *(In upwork)</sub>
#
# 5. What's Worst 5 people in earnings amount most frequent words in thier describtions.<sub> *(In upwork)</sub>
#
# 6. What are the most appending skills in the jobs per profession and country.<sub> *(In upwork & LinkedIn)</sub>
#
# 7. What are the Top 10 skills in earnings and in count. <sub> *(In upwork & LinkedIn)</sub>
#
# 8. Correlation between Earnings amount, Years of Exp, Hour rate & Feedback in Upwork.
#
# 9. Does the Consultations offers affect the Earnings amount strongly.
#
# 10. Top 3 countries in total freelancers earnings Vs Top 3 countries in freelancers count <sub> *(In upwork & guru)</sub>
#
# 11. Jobs count per Jobs location per profession.
#
# 12. Where are the most job loactions in general per profession.
#
# 13. What's the average salary per proffision & per country.
#
# 14. What's the most common Employment type per data jobs in general.
#
# 15. Jobs count vs listing dates per proffision to see thier growth trends.
#
# 16. most common Earning abount, hour rate, exp years per proffision in Upwork.

# %% [markdown]
# #### **Important note:**
# I am going to use  **`pandasql`** to read the data from the dfs so I can create plots more easly using SQL<br>
# queries inside python.

# %% [markdown]
# ## <center><strong>Importing the <span style= 'color: #48e0dc'>Packeges

# %%
import os
import warnings
import matplotlib
import pandasql           as ps
import pandas             as pd
import numpy              as np
import seaborn            as sns
import matplotlib.pyplot  as plt

from google.cloud         import bigquery
from wordcloud            import WordCloud
from operator             import itemgetter
from collections          import Counter
from matplotlib.colors    import ListedColormap

# %%
# %matplotlib inline
plt.rcParams['font.family'] = 'Candara'

warnings.filterwarnings('ignore')

credentials_path :str = '../credentials.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credentials_path

FONT             :int  = 20
COLORS           :list = ['#51fcc6', '#48e0dc', '#5cd3f7', '#4895e0', '#517afc']
GREYS            :list = ['#999999', '#777777', '#555555']

NUMERICS         :list = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64',
                          'uint16', 'uint32', 'uint64']

# %% [markdown]
# ## <center><strong>Loading the data & basic data <span style= 'color: #5cd3f7'>Cleaning

# %%
project_id :str = 'data-jobs-analysis-db'
dataset_id :str = 'data_jobs_analysis_db'

query_pandas  = lambda q: ps.sqldf(q, globals())
client        = bigquery.Client(project= project_id)

linkedin_jobs    = client.query(f'SELECT * FROM {dataset_id}.linkedin_jobs;').to_dataframe()
upwork_profiles  = client.query(f'SELECT * FROM {dataset_id}.upwork_profiles;').to_dataframe()
guru_profiles    = client.query(f'SELECT * FROM {dataset_id}.guru_profiles;').to_dataframe()

# %%
cm = sns.light_palette(COLORS[0], as_cmap=True)

linkedin_jobs.drop(['describtion', 'jobs_links', 'jobs_titles', 'skills']
                   , axis= 1).sample(5).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_49fcf_row0_col9 {
#   background-color: #7ff9d2;
#   color: #000000;
# }
# #T_49fcf_row0_col10, #T_49fcf_row1_col10, #T_49fcf_row1_col12, #T_49fcf_row2_col10, #T_49fcf_row2_col12, #T_49fcf_row3_col10, #T_49fcf_row4_col9, #T_49fcf_row4_col10 {
#   background-color: #eaf3ef;
#   color: #000000;
# }
# #T_49fcf_row0_col12, #T_49fcf_row4_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_49fcf_row1_col9, #T_49fcf_row3_col12 {
#   background-color: #51fcc6;
#   color: #000000;
# }
# #T_49fcf_row2_col9 {
#   background-color: #74facf;
#   color: #000000;
# }
# #T_49fcf_row3_col9 {
#   background-color: #cdf4e7;
#   color: #000000;
# }
# </style>
# <table id="T_49fcf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49fcf_level0_col0" class="col_heading level0 col0" >jobs_locations</th>
#       <th id="T_49fcf_level0_col1" class="col_heading level0 col1" >listing_dates</th>
#       <th id="T_49fcf_level0_col2" class="col_heading level0 col2" >companies_names</th>
#       <th id="T_49fcf_level0_col3" class="col_heading level0 col3" >location_type</th>
#       <th id="T_49fcf_level0_col4" class="col_heading level0 col4" >employment_type</th>
#       <th id="T_49fcf_level0_col5" class="col_heading level0 col5" >industry</th>
#       <th id="T_49fcf_level0_col6" class="col_heading level0 col6" >reqierd_credential</th>
#       <th id="T_49fcf_level0_col7" class="col_heading level0 col7" >country</th>
#       <th id="T_49fcf_level0_col8" class="col_heading level0 col8" >job_title</th>
#       <th id="T_49fcf_level0_col9" class="col_heading level0 col9" >total_jobs</th>
#       <th id="T_49fcf_level0_col10" class="col_heading level0 col10" >salary</th>
#       <th id="T_49fcf_level0_col11" class="col_heading level0 col11" >programming_lang</th>
#       <th id="T_49fcf_level0_col12" class="col_heading level0 col12" >exp_years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49fcf_level0_row0" class="row_heading level0 row0" >749</th>
#       <td id="T_49fcf_row0_col0" class="data row0 col0" >Concord, CA</td>
#       <td id="T_49fcf_row0_col1" class="data row0 col1" >2023-05-11</td>
#       <td id="T_49fcf_row0_col2" class="data row0 col2" >Perfict</td>
#       <td id="T_49fcf_row0_col3" class="data row0 col3" >Remote</td>
#       <td id="T_49fcf_row0_col4" class="data row0 col4" >CONTRACTOR</td>
#       <td id="T_49fcf_row0_col5" class="data row0 col5" >Staffing and Recruiting</td>
#       <td id="T_49fcf_row0_col6" class="data row0 col6" >bachelor degree</td>
#       <td id="T_49fcf_row0_col7" class="data row0 col7" >European Union</td>
#       <td id="T_49fcf_row0_col8" class="data row0 col8" >Data scientist</td>
#       <td id="T_49fcf_row0_col9" class="data row0 col9" >142000</td>
#       <td id="T_49fcf_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_49fcf_row0_col11" class="data row0 col11" >['sql' 'python']</td>
#       <td id="T_49fcf_row0_col12" class="data row0 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_49fcf_level0_row1" class="row_heading level0 row1" >3319</th>
#       <td id="T_49fcf_row1_col0" class="data row1 col0" >Campbell, CA</td>
#       <td id="T_49fcf_row1_col1" class="data row1 col1" >2023-06-23</td>
#       <td id="T_49fcf_row1_col2" class="data row1 col2" >Platinum Enterprise Solutions, Inc.</td>
#       <td id="T_49fcf_row1_col3" class="data row1 col3" >Hybrid</td>
#       <td id="T_49fcf_row1_col4" class="data row1 col4" >FULL_TIME</td>
#       <td id="T_49fcf_row1_col5" class="data row1 col5" >Staffing and Recruiting</td>
#       <td id="T_49fcf_row1_col6" class="data row1 col6" >bachelor degree</td>
#       <td id="T_49fcf_row1_col7" class="data row1 col7" >United States</td>
#       <td id="T_49fcf_row1_col8" class="data row1 col8" >Data analyst</td>
#       <td id="T_49fcf_row1_col9" class="data row1 col9" >202000</td>
#       <td id="T_49fcf_row1_col10" class="data row1 col10" >nan</td>
#       <td id="T_49fcf_row1_col11" class="data row1 col11" >['java' 'python']</td>
#       <td id="T_49fcf_row1_col12" class="data row1 col12" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_49fcf_level0_row2" class="row_heading level0 row2" >754</th>
#       <td id="T_49fcf_row2_col0" class="data row2 col0" >Concord, CA</td>
#       <td id="T_49fcf_row2_col1" class="data row2 col1" >2023-05-23</td>
#       <td id="T_49fcf_row2_col2" class="data row2 col2" >Perfict</td>
#       <td id="T_49fcf_row2_col3" class="data row2 col3" >Remote</td>
#       <td id="T_49fcf_row2_col4" class="data row2 col4" >FULL_TIME</td>
#       <td id="T_49fcf_row2_col5" class="data row2 col5" >Staffing and Recruiting</td>
#       <td id="T_49fcf_row2_col6" class="data row2 col6" >bachelor degree</td>
#       <td id="T_49fcf_row2_col7" class="data row2 col7" >European Union</td>
#       <td id="T_49fcf_row2_col8" class="data row2 col8" >Data analyst</td>
#       <td id="T_49fcf_row2_col9" class="data row2 col9" >156000</td>
#       <td id="T_49fcf_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_49fcf_row2_col11" class="data row2 col11" >['sql']</td>
#       <td id="T_49fcf_row2_col12" class="data row2 col12" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_49fcf_level0_row3" class="row_heading level0 row3" >3051</th>
#       <td id="T_49fcf_row3_col0" class="data row3 col0" >Bay Point, CA</td>
#       <td id="T_49fcf_row3_col1" class="data row3 col1" >2023-06-01</td>
#       <td id="T_49fcf_row3_col2" class="data row3 col2" >Donato Technologies, Inc.</td>
#       <td id="T_49fcf_row3_col3" class="data row3 col3" >From office</td>
#       <td id="T_49fcf_row3_col4" class="data row3 col4" >FULL_TIME</td>
#       <td id="T_49fcf_row3_col5" class="data row3 col5" >IT Services and IT Consulting</td>
#       <td id="T_49fcf_row3_col6" class="data row3 col6" >bachelor degree</td>
#       <td id="T_49fcf_row3_col7" class="data row3 col7" >European Union</td>
#       <td id="T_49fcf_row3_col8" class="data row3 col8" >Data engineer</td>
#       <td id="T_49fcf_row3_col9" class="data row3 col9" >39000</td>
#       <td id="T_49fcf_row3_col10" class="data row3 col10" >nan</td>
#       <td id="T_49fcf_row3_col11" class="data row3 col11" >['js' 'sql' 'python']</td>
#       <td id="T_49fcf_row3_col12" class="data row3 col12" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_49fcf_level0_row4" class="row_heading level0 row4" >2950</th>
#       <td id="T_49fcf_row4_col0" class="data row4 col0" >El Cerrito, CA</td>
#       <td id="T_49fcf_row4_col1" class="data row4 col1" >2022-10-27</td>
#       <td id="T_49fcf_row4_col2" class="data row4 col2" >Recruiting from Scratch</td>
#       <td id="T_49fcf_row4_col3" class="data row4 col3" >Remote</td>
#       <td id="T_49fcf_row4_col4" class="data row4 col4" >FULL_TIME</td>
#       <td id="T_49fcf_row4_col5" class="data row4 col5" >Staffing and Recruiting</td>
#       <td id="T_49fcf_row4_col6" class="data row4 col6" >bachelor degree</td>
#       <td id="T_49fcf_row4_col7" class="data row4 col7" >European Union</td>
#       <td id="T_49fcf_row4_col8" class="data row4 col8" >ML developer</td>
#       <td id="T_49fcf_row4_col9" class="data row4 col9" >989</td>
#       <td id="T_49fcf_row4_col10" class="data row4 col10" >182500.000000</td>
#       <td id="T_49fcf_row4_col11" class="data row4 col11" >['scala' 'c++' 'python']</td>
#       <td id="T_49fcf_row4_col12" class="data row4 col12" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette(COLORS[2], as_cmap=True)

upwork_profiles.drop(['describtion', 'skills']
                   , axis= 1).sample(5).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_9c0f4_row0_col0, #T_9c0f4_row1_col0, #T_9c0f4_row2_col0, #T_9c0f4_row3_col0, #T_9c0f4_row3_col8, #T_9c0f4_row4_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_9c0f4_row0_col1, #T_9c0f4_row0_col10, #T_9c0f4_row1_col10, #T_9c0f4_row2_col8, #T_9c0f4_row2_col10, #T_9c0f4_row3_col10, #T_9c0f4_row4_col9, #T_9c0f4_row4_col10 {
#   background-color: #eef1f2;
#   color: #000000;
# }
# #T_9c0f4_row0_col8 {
#   background-color: #eaf0f3;
#   color: #000000;
# }
# #T_9c0f4_row0_col9 {
#   background-color: #b7e6f4;
#   color: #000000;
# }
# #T_9c0f4_row1_col1 {
#   background-color: #63d4f7;
#   color: #000000;
# }
# #T_9c0f4_row1_col8, #T_9c0f4_row3_col1, #T_9c0f4_row3_col9 {
#   background-color: #5cd3f7;
#   color: #000000;
# }
# #T_9c0f4_row1_col9 {
#   background-color: #e5eff3;
#   color: #000000;
# }
# #T_9c0f4_row2_col1 {
#   background-color: #a1e1f5;
#   color: #000000;
# }
# #T_9c0f4_row2_col9 {
#   background-color: #d6ecf3;
#   color: #000000;
# }
# #T_9c0f4_row4_col1 {
#   background-color: #c4e8f4;
#   color: #000000;
# }
# #T_9c0f4_row4_col8 {
#   background-color: #ebf0f3;
#   color: #000000;
# }
# </style>
# <table id="T_9c0f4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9c0f4_level0_col0" class="col_heading level0 col0" >Unnamed__0</th>
#       <th id="T_9c0f4_level0_col1" class="col_heading level0 col1" >feedback</th>
#       <th id="T_9c0f4_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_9c0f4_level0_col3" class="col_heading level0 col3" >job_title</th>
#       <th id="T_9c0f4_level0_col4" class="col_heading level0 col4" >country</th>
#       <th id="T_9c0f4_level0_col5" class="col_heading level0 col5" >consultations_offers</th>
#       <th id="T_9c0f4_level0_col6" class="col_heading level0 col6" >data_job_title</th>
#       <th id="T_9c0f4_level0_col7" class="col_heading level0 col7" >new_columns</th>
#       <th id="T_9c0f4_level0_col8" class="col_heading level0 col8" >earnings_amount_new</th>
#       <th id="T_9c0f4_level0_col9" class="col_heading level0 col9" >hour_rate_new</th>
#       <th id="T_9c0f4_level0_col10" class="col_heading level0 col10" >exp_years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9c0f4_level0_row0" class="row_heading level0 row0" >743</th>
#       <td id="T_9c0f4_row0_col0" class="data row0 col0" ><NA></td>
#       <td id="T_9c0f4_row0_col1" class="data row0 col1" >79.000000</td>
#       <td id="T_9c0f4_row0_col2" class="data row0 col2" >Muhammad U.</td>
#       <td id="T_9c0f4_row0_col3" class="data row0 col3" >Data Scientist</td>
#       <td id="T_9c0f4_row0_col4" class="data row0 col4" >Pakistan</td>
#       <td id="T_9c0f4_row0_col5" class="data row0 col5" >Doesn't offer consultations</td>
#       <td id="T_9c0f4_row0_col6" class="data row0 col6" >Data scientist</td>
#       <td id="T_9c0f4_row0_col7" class="data row0 col7" >{'earnings_amount_new': 4000, 'hour_rate_new': 25.0}</td>
#       <td id="T_9c0f4_row0_col8" class="data row0 col8" >4000</td>
#       <td id="T_9c0f4_row0_col9" class="data row0 col9" >25.000000</td>
#       <td id="T_9c0f4_row0_col10" class="data row0 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c0f4_level0_row1" class="row_heading level0 row1" >758</th>
#       <td id="T_9c0f4_row1_col0" class="data row1 col0" ><NA></td>
#       <td id="T_9c0f4_row1_col1" class="data row1 col1" >99.000000</td>
#       <td id="T_9c0f4_row1_col2" class="data row1 col2" >Asad F.</td>
#       <td id="T_9c0f4_row1_col3" class="data row1 col3" >Expert in Web Scraping, Data Mining, RealEstate, Web Research</td>
#       <td id="T_9c0f4_row1_col4" class="data row1 col4" >Pakistan</td>
#       <td id="T_9c0f4_row1_col5" class="data row1 col5" >Doesn't offer consultations</td>
#       <td id="T_9c0f4_row1_col6" class="data row1 col6" >Data entry</td>
#       <td id="T_9c0f4_row1_col7" class="data row1 col7" >{'earnings_amount_new': 100000, 'hour_rate_new': 10.0}</td>
#       <td id="T_9c0f4_row1_col8" class="data row1 col8" >100000</td>
#       <td id="T_9c0f4_row1_col9" class="data row1 col9" >10.000000</td>
#       <td id="T_9c0f4_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c0f4_level0_row2" class="row_heading level0 row2" >892</th>
#       <td id="T_9c0f4_row2_col0" class="data row2 col0" ><NA></td>
#       <td id="T_9c0f4_row2_col1" class="data row2 col1" >90.000000</td>
#       <td id="T_9c0f4_row2_col2" class="data row2 col2" >Aboulhassan A.</td>
#       <td id="T_9c0f4_row2_col3" class="data row2 col3" >Machine Learning&  Data science & Data engineer</td>
#       <td id="T_9c0f4_row2_col4" class="data row2 col4" >Morocco</td>
#       <td id="T_9c0f4_row2_col5" class="data row2 col5" >Doesn't offer consultations</td>
#       <td id="T_9c0f4_row2_col6" class="data row2 col6" >Machine Learning</td>
#       <td id="T_9c0f4_row2_col7" class="data row2 col7" >{'earnings_amount_new': 1000, 'hour_rate_new': 15.0}</td>
#       <td id="T_9c0f4_row2_col8" class="data row2 col8" >1000</td>
#       <td id="T_9c0f4_row2_col9" class="data row2 col9" >15.000000</td>
#       <td id="T_9c0f4_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_9c0f4_level0_row3" class="row_heading level0 row3" >51</th>
#       <td id="T_9c0f4_row3_col0" class="data row3 col0" ><NA></td>
#       <td id="T_9c0f4_row3_col1" class="data row3 col1" >100.000000</td>
#       <td id="T_9c0f4_row3_col2" class="data row3 col2" >Fahad S.</td>
#       <td id="T_9c0f4_row3_col3" class="data row3 col3" >Expert Python / Golang / Scala Developer - Data Engineer</td>
#       <td id="T_9c0f4_row3_col4" class="data row3 col4" >Pakistan</td>
#       <td id="T_9c0f4_row3_col5" class="data row3 col5" >Offers consultations</td>
#       <td id="T_9c0f4_row3_col6" class="data row3 col6" >Data Engineering</td>
#       <td id="T_9c0f4_row3_col7" class="data row3 col7" >{'earnings_amount_new': None, 'hour_rate_new': 55.0}</td>
#       <td id="T_9c0f4_row3_col8" class="data row3 col8" ><NA></td>
#       <td id="T_9c0f4_row3_col9" class="data row3 col9" >55.000000</td>
#       <td id="T_9c0f4_row3_col10" class="data row3 col10" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_9c0f4_level0_row4" class="row_heading level0 row4" >803</th>
#       <td id="T_9c0f4_row4_col0" class="data row4 col0" ><NA></td>
#       <td id="T_9c0f4_row4_col1" class="data row4 col1" >85.000000</td>
#       <td id="T_9c0f4_row4_col2" class="data row4 col2" >Sadheer K.</td>
#       <td id="T_9c0f4_row4_col3" class="data row4 col3" >Excel Spreadsheet | Google Sheets | Data Analytics | Specialist</td>
#       <td id="T_9c0f4_row4_col4" class="data row4 col4" >Pakistan</td>
#       <td id="T_9c0f4_row4_col5" class="data row4 col5" >Doesn't offer consultations</td>
#       <td id="T_9c0f4_row4_col6" class="data row4 col6" >Data Analyst</td>
#       <td id="T_9c0f4_row4_col7" class="data row4 col7" >{'earnings_amount_new': 3000, 'hour_rate_new': 7.0}</td>
#       <td id="T_9c0f4_row4_col8" class="data row4 col8" >3000</td>
#       <td id="T_9c0f4_row4_col9" class="data row4 col9" >7.000000</td>
#       <td id="T_9c0f4_row4_col10" class="data row4 col10" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette(COLORS[4], as_cmap=True)

guru_profiles.drop(['describtion', 'skills']
                   , axis= 1).sample(5).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_db716_row0_col0, #T_db716_row1_col0, #T_db716_row2_col0, #T_db716_row3_col0, #T_db716_row4_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_db716_row0_col4, #T_db716_row3_col8 {
#   background-color: #517afc;
#   color: #f1f1f1;
# }
# #T_db716_row0_col7, #T_db716_row0_col9, #T_db716_row1_col4, #T_db716_row1_col7, #T_db716_row1_col9, #T_db716_row2_col4, #T_db716_row2_col7, #T_db716_row2_col9, #T_db716_row3_col4, #T_db716_row3_col7, #T_db716_row3_col9, #T_db716_row4_col4, #T_db716_row4_col7, #T_db716_row4_col8, #T_db716_row4_col9 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_db716_row0_col8 {
#   background-color: #aabcf7;
#   color: #000000;
# }
# #T_db716_row1_col8 {
#   background-color: #e5e8f3;
#   color: #000000;
# }
# #T_db716_row2_col8 {
#   background-color: #ebecf3;
#   color: #000000;
# }
# </style>
# <table id="T_db716">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_db716_level0_col0" class="col_heading level0 col0" >Unnamed__0</th>
#       <th id="T_db716_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_db716_level0_col2" class="col_heading level0 col2" >job_title</th>
#       <th id="T_db716_level0_col3" class="col_heading level0 col3" >addresse</th>
#       <th id="T_db716_level0_col4" class="col_heading level0 col4" >minimum_pay</th>
#       <th id="T_db716_level0_col5" class="col_heading level0 col5" >data_job_title</th>
#       <th id="T_db716_level0_col6" class="col_heading level0 col6" >new_columns</th>
#       <th id="T_db716_level0_col7" class="col_heading level0 col7" >earnings_amount_new</th>
#       <th id="T_db716_level0_col8" class="col_heading level0 col8" >hour_rate_new</th>
#       <th id="T_db716_level0_col9" class="col_heading level0 col9" >feedback_new</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db716_level0_row0" class="row_heading level0 row0" >1627</th>
#       <td id="T_db716_row0_col0" class="data row0 col0" ><NA></td>
#       <td id="T_db716_row0_col1" class="data row0 col1" >prashantjha</td>
#       <td id="T_db716_row0_col2" class="data row0 col2" >Data Analytics & Engineering</td>
#       <td id="T_db716_row0_col3" class="data row0 col3" >New Delhi, Delhi, India</td>
#       <td id="T_db716_row0_col4" class="data row0 col4" >100.000000</td>
#       <td id="T_db716_row0_col5" class="data row0 col5" >Data Engineering</td>
#       <td id="T_db716_row0_col6" class="data row0 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 20.0}</td>
#       <td id="T_db716_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_db716_row0_col8" class="data row0 col8" >20.000000</td>
#       <td id="T_db716_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db716_level0_row1" class="row_heading level0 row1" >966</th>
#       <td id="T_db716_row1_col0" class="data row1 col0" ><NA></td>
#       <td id="T_db716_row1_col1" class="data row1 col1" >Merna Hesham</td>
#       <td id="T_db716_row1_col2" class="data row1 col2" >Python code for Machine Learning Problem</td>
#       <td id="T_db716_row1_col3" class="data row1 col3" >Giza, Al Jizah, Egypt</td>
#       <td id="T_db716_row1_col4" class="data row1 col4" >25.000000</td>
#       <td id="T_db716_row1_col5" class="data row1 col5" >Machine Learning</td>
#       <td id="T_db716_row1_col6" class="data row1 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 10.0}</td>
#       <td id="T_db716_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_db716_row1_col8" class="data row1 col8" >10.000000</td>
#       <td id="T_db716_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db716_level0_row2" class="row_heading level0 row2" >416</th>
#       <td id="T_db716_row2_col0" class="data row2 col0" ><NA></td>
#       <td id="T_db716_row2_col1" class="data row2 col1" >Anna Martirosyan</td>
#       <td id="T_db716_row2_col2" class="data row2 col2" >Data Analyst</td>
#       <td id="T_db716_row2_col3" class="data row2 col3" >Yerevan, Yerevan, Armenia</td>
#       <td id="T_db716_row2_col4" class="data row2 col4" >25.000000</td>
#       <td id="T_db716_row2_col5" class="data row2 col5" >Data Analyst</td>
#       <td id="T_db716_row2_col6" class="data row2 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 9.0}</td>
#       <td id="T_db716_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_db716_row2_col8" class="data row2 col8" >9.000000</td>
#       <td id="T_db716_row2_col9" class="data row2 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db716_level0_row3" class="row_heading level0 row3" >720</th>
#       <td id="T_db716_row3_col0" class="data row3 col0" ><NA></td>
#       <td id="T_db716_row3_col1" class="data row3 col1" >Anitha Thekkedeth</td>
#       <td id="T_db716_row3_col2" class="data row3 col2" >Clinical Data Scientist</td>
#       <td id="T_db716_row3_col3" class="data row3 col3" >Brampton, Ontario, Canada</td>
#       <td id="T_db716_row3_col4" class="data row3 col4" >25.000000</td>
#       <td id="T_db716_row3_col5" class="data row3 col5" >Data scientist</td>
#       <td id="T_db716_row3_col6" class="data row3 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 35.0}</td>
#       <td id="T_db716_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_db716_row3_col8" class="data row3 col8" >35.000000</td>
#       <td id="T_db716_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_db716_level0_row4" class="row_heading level0 row4" >183</th>
#       <td id="T_db716_row4_col0" class="data row4 col0" ><NA></td>
#       <td id="T_db716_row4_col1" class="data row4 col1" >Abhishek pandey 69</td>
#       <td id="T_db716_row4_col2" class="data row4 col2" >Data entry operator</td>
#       <td id="T_db716_row4_col3" class="data row4 col3" >Katni, Madhya Pradesh, India</td>
#       <td id="T_db716_row4_col4" class="data row4 col4" >25.000000</td>
#       <td id="T_db716_row4_col5" class="data row4 col5" >Data entry</td>
#       <td id="T_db716_row4_col6" class="data row4 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 8.0}</td>
#       <td id="T_db716_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_db716_row4_col8" class="data row4 col8" >8.000000</td>
#       <td id="T_db716_row4_col9" class="data row4 col9" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Basic cleaning:**

# %%
def tucky_method(array: np.array, indecies= True) -> np.array:
    """
    This function works with any list-like numerical object
    (don't work with pandas series's) and returns the indexes
    of the found outliers in the array.
    
    :Params: Takes only the series.
    :Returns: S list of the outliers indexes.
    """
    
    Q3 = np.quantile(array, 0.75)
    Q1 = np.quantile(array, 0.25)
    IQR = Q3 - Q1
    
    upper_range = Q3 + (IQR * 1.5)
    lower_range = Q1 - (IQR * 1.5)
    
    outliers = [x for x in array if ((x < lower_range) | (x > upper_range))]
    print(f"Found {len(outliers)} outliers from {len(array)} length series!")
    
    return outliers

# %%
upwork_profiles.drop(['Unnamed__0', 'new_columns'], axis= 1, inplace= True)
guru_profiles.drop(['Unnamed__0', 'new_columns'], axis= 1, inplace= True)

linkedin_jobs.drop(['jobs_links'], axis= 1, inplace= True)

linkedin_jobs['salary'] = linkedin_jobs['salary'].where((linkedin_jobs.salary < 70) |
                                                        (linkedin_jobs.salary > 10_000) &
                                                        (linkedin_jobs.salary > 5))

per_hour_or_year_map = lambda salary: 'per year' if salary > 10_000 else 'per hour' if salary < 100 else np.nan
linkedin_jobs['per_hour_or_year'] = linkedin_jobs['salary'].apply(per_hour_or_year_map)

# %%
outliers = tucky_method(linkedin_jobs[linkedin_jobs['per_hour_or_year'] == 'per year']['salary'].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(linkedin_jobs['salary'], outliers)))
linkedin_jobs = linkedin_jobs.drop(outliers_indexes)

# outliers = z_score(linkedin_jobs['salary'].to_numpy())
# outliers_indexes = np.array(*np.where(np.isin(base_videos['viewCount'], outliers)))
# temp_base_videos = base_videos.drop(outliers_indexes)
# Out:
# Found 77 outliers from 964 length series!

# %% [markdown]
# ## <center><strong><span style= 'color: #5cd3f7'>Visualizing</span> the data (part 1)

# %%
def add_bar_labels(x,y, ax, scaler= 0):
    for i in range(len(x)):
        ax.text(i, y[i] + scaler , '{:,}'.format(y[i]), ha = 'center')

# %%
fig, (ax1, ax2) = plt.subplots(nrows= 2)

countries = ['\'United States\'', '\'European Union\'']

colors_temp = [COLORS[0]] * 1
colors_temp += ['lightgrey'] * 5

for ax, country in zip([ax1, ax2], countries):
    
    data = query_pandas(f'''SELECT total_jobs,
                                 job_title,
                                 country
                           FROM linkedin_jobs
                           WHERE country = {country}
                           GROUP BY job_title
                           ORDER BY total_jobs DESC;''')
    
    ax.bar(x=      data['job_title'],
           height= data['total_jobs'],
           color=  colors_temp)
    
    ax.spines[['right', 'top']].set_visible(False)

    ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
    
    ax.set_title(f'Available Jobs per job title in the {country}', fontsize= FONT, pad= 19)
    ax.set_ylabel('Total jobs', fontsize= FONT * 3.5/5)
    
    if ax is ax1:
        add_bar_labels(data['job_title'], data['total_jobs'], ax, scaler= 15000)
        
    if ax is ax2:
        add_bar_labels(data['job_title'], data['total_jobs'], ax, scaler= 5000)

        
fig.tight_layout(h_pad=0.5, w_pad=5)
fig.set_size_inches(13, 12)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)

platforms   : list = ['guru', 'upwork']
labels      : list = ['Earned money', 'Didn\'t earn money']
colors_temp : list = [COLORS[1], 'lightgrey']
explode     : list = [0.2, 0.2]

for ax, platform in zip([ax1, ax2], platforms):
    # The first row in the queried table below contains the people who have earned money count
    data = query_pandas(f'''SELECT COUNT(*) AS total_profiles
                           FROM {platform}_profiles
                           WHERE earnings_amount_new > 0
                           
                           UNION ALL
                           
                           SELECT COUNT(*) AS total_profiles
                           FROM {platform}_profiles
                           WHERE earnings_amount_new IS NULL OR 
                                 earnings_amount_new = 0;''')


    # Plot the pie chart on the current axis
    # ax.pie(counts, labels=labels, autopct='%2.1f%%', pctdistance=0.85, labeldistance=1.2, colors= colors_temp)
    
    ax.pie(data['total_profiles'], labels=labels, autopct='%2.1f%%',
           pctdistance=0.85, labeldistance=1.2, colors=colors_temp,
           startangle=90)
    
    ax.set_title(f'How many people earned money in {platform.title()}', fontsize= FONT, pad= 50)
                 
    centre_circle = plt.Circle((0, 0), 0.75, fc='white')
    ax.add_artist(centre_circle)

fig.tight_layout(w_pad=7)
fig.set_size_inches(13, 10)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

width = 0.27

data = query_pandas(f'''SELECT AVG(salary) AS avg_salary,
                               country,
                               job_title

                        FROM linkedin_jobs
                        WHERE salary > 100 
                        GROUP BY country, job_title
                        ORDER BY avg_salary DESC;''')

us_data = data[data['country'] == 'United States']
eu_data = data[data['country'] == 'European Union']

positions_us = range(len(us_data))
positions_eu = [pos + width for pos in positions_us]


ax.bar(positions_us, us_data['avg_salary'], width,
       align='center', label='United States',
       color= COLORS[2])

ax.bar(positions_eu, eu_data['avg_salary'], width,
       align='center', label='European Union',
       color= 'lightgrey')


ax.spines[['right', 'top']].set_visible(False)
ax.set_xticks([pos + width/2 for pos in positions_us])
ax.set_xticklabels(us_data['job_title'], ha='center')

ax.set_title(f'Median Salary per data job in the US and EU', fontsize= FONT, pad= 50)
ax.set_xlabel('Job Title',      fontsize= FONT * 3.5/5)
ax.set_ylabel('Average Salary', fontsize= FONT * 3.5/5)


ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

ax.legend(fontsize="14")
fig.set_size_inches(13, 6)
fig.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)

cmap      = ListedColormap(COLORS)
grey_cmap = ListedColormap(GREYS)

top_5_describtions = query_pandas('''SELECT describtion
                                     FROM upwork_profiles
                                     WHERE earnings_amount_new IS NOT NULL
                                     ORDER BY earnings_amount_new DESC
                                     LIMIT 5;''')['describtion'].str.cat(sep= ' ')

least_5_describtions = query_pandas('''SELECT describtion
                                       FROM upwork_profiles
                                       WHERE earnings_amount_new IS NOT NULL
                                       ORDER BY earnings_amount_new
                                       LIMIT 5;''')['describtion'].str.cat(sep= ' ')

wordcloud_ax1 = WordCloud(collocations= False, background_color= 'white',
                      max_font_size= 45, colormap= cmap).generate(top_5_describtions)


wordcloud_ax2 = WordCloud(collocations= False, background_color= 'white',
                      max_font_size= 45, colormap= grey_cmap).generate(least_5_describtions)

ax1.set_title(f'Top 5 Freelancers\'s \nDescribtions Most Frequent Words', fontsize= FONT, pad= 50)
ax2.set_title(f'Least 5 Freelancers\'s \nDescribtions Most Frequent', fontsize= FONT, pad= 50)

ax1.imshow(wordcloud_ax1, interpolation='bilinear')
ax1.axis("off")

ax2.imshow(wordcloud_ax2, interpolation='bilinear')
ax2.axis("off")

fig.set_size_inches(13, 6)
plt.tight_layout(w_pad= 5)
plt.show()

# %%
fig, axes = plt.subplots(ncols= 2)

for i, job_title in enumerate(linkedin_jobs['job_title'].unique()):

    skills_count_us = dict(Counter(np.concatenate(linkedin_jobs[
                           (linkedin_jobs['job_title'] == job_title) &
                           (linkedin_jobs['country']   == 'United States')].reset_index()['skills'])))
    
    skills_count_eu = dict(Counter(np.concatenate(linkedin_jobs[
                           (linkedin_jobs['job_title'] == job_title) &
                           (linkedin_jobs['country']   == 'European Union')].reset_index()['skills'])))

    top_10_skills_count_us = {k: v for k, v in sorted(skills_count_us.items(), key=lambda item: item[1], reverse=True)[:10]}
    top_10_skills_count_eu = {k: v for k, v in sorted(skills_count_eu.items(), key=lambda item: item[1], reverse=True)[:10]}

    
    for top_10_skills_count in (top_10_skills_count_us,
                                top_10_skills_count_eu):
        
        labels = list(top_10_skills_count.keys())
        values = list(top_10_skills_count.values())

        axes[i].bar(labels, values, width,
                   align='center', label='United States',
                   color= COLORS[2])

        axes[i].bar(labels, values, width,
                   align='center', label='European Union',
                   color= 'lightgrey')

# %%
linkedin_jobs['country']
# Out:
# 0       European Union
# 1        United States
# 2       European Union
# 3        United States
# 4        United States
#              ...
# 3450     United States
# 3451     United States
# 3452    European Union
# 3453     United States
# 3454    European Union
# Name: country, Length: 3378, dtype: object

# %%
plt.bar([label.title() for label in labels], values)
# Out:
# <BarContainer object of 10 artists>

# %%
    skills_count_eu = dict(Counter(np.concatenate(linkedin_jobs[
                           (linkedin_jobs['job_title'] == job_title) &
                           (linkedin_jobs['country']   == 'European Union')].reset_index()['skills'])))

# %%
skills_count_eu
# Out:
# {'attention to detail': 93,
#  'excel': 200,
#  'sas': 33,
#  'time management': 30,
#  'aws': 59,
#  'data analysis': 7,
#  'data accuracy': 3,
#  'data entry software': 2,
#  'data cleansing': 1,
#  'google sheets': 4,
#  'data input': 2,
#  'database management': 4,
#  'data analytics': 2,
#  'etl': 2,
#  'typing speed': 8,
#  'tableau': 1,
#  'data visualization': 1,
#  'statistical analysis': 1,
#  'numpy': 1,
#  'data pipelines': 1,
#  'pandas': 1,
#  'data capture': 1,
#  'data security': 1,
#  'data presentation': 1}
