# %% [markdown]
# ## <center><strong>Notebook describtion & Our <span style= 'color: #51fcc6'>Questions</span>

# %% [markdown]
# In this notebook we are going to create the charts that we are going to use in the final pdf report and the tools we are going<br>
# to use are matplotlib and seaborn.

# %% [markdown]
# #### **Questions we are going to awnser:**
# 1. How many jobs are available per country and per profession on Likedin.
#
# 2. What's the ratio between people who earned money on UpWork Vs Guru.
#
# 3. Average salary per profession and per country on LinkedIn.
#
# 4. What's Top 5 people in earnings amount most frequent words in thier describtions.<sub> *(In upwork)</sub>
#
# 5. What's Worst 5 people in earnings amount most frequent words in thier describtions.<sub> *(In upwork)</sub>
#
# 6. What are the most appending skills in the jobs per profession and country.<sub> *(In upwork & LinkedIn)</sub>
#
# 7. What are the Top 10 skills in earnings and in count. <sub> *(In upwork & LinkedIn)</sub>
#
# 8. Correlation between Earnings amount, Years of Exp, Hour rate & Feedback in Upwork.
#
# 9. Does the Consultations offers affect the Earnings amount strongly.
#
# 10. Top 3 countries in total freelancers earnings Vs Top 3 countries in freelancers count <sub> *(In upwork & guru)</sub>
#
# 11. Jobs count per Jobs location per profession.
#
# 12. Where are the most job loactions in general per profession.
#
# 13. What's the average salary per proffision & per country.
#
# 14. What's the most common Employment type per data jobs in general.
#
# 15. Jobs count vs listing dates per proffision to see thier growth trends.
#
# 16. most common Earning abount, hour rate, exp years per proffision in Upwork.

# %% [markdown]
# #### **Important note:**
# I am going to use  **`pandasql`** to read the data from the dfs so I can create plots more easly using SQL<br>
# queries inside python.

# %% [markdown]
# ## <center><strong>Importing the <span style= 'color: #48e0dc'>Packeges

# %%
import os
import warnings
import matplotlib
import pandasql           as ps
import pandas             as pd
import numpy              as np
import seaborn            as sns
import matplotlib.pyplot  as plt

from google.cloud         import bigquery
from wordcloud            import WordCloud
from operator             import itemgetter
from collections          import Counter
from matplotlib.colors    import ListedColormap

# %%
# %matplotlib inline
plt.rcParams['font.family'] = 'Candara'

warnings.filterwarnings('ignore')

credentials_path :str = '../credentials.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credentials_path

FONT             :int  = 20
COLORS           :list = ['#51fcc6', '#48e0dc', '#5cd3f7', '#4895e0', '#517afc']
GREYS            :list = ['#999999', '#777777', '#555555']

NUMERICS         :list = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64',
                          'uint16', 'uint32', 'uint64']

# %% [markdown]
# ## <center><strong>Loading the data & basic data <span style= 'color: #5cd3f7'>Cleaning

# %%
project_id :str = 'data-jobs-analysis-db'
dataset_id :str = 'data_jobs_analysis_db'

query_pandas  = lambda q: ps.sqldf(q, globals())
client        = bigquery.Client(project= project_id)

linkedin_jobs    = client.query(f'SELECT * FROM {dataset_id}.linkedin_jobs;').to_dataframe()
upwork_profiles  = client.query(f'SELECT * FROM {dataset_id}.upwork_profiles;').to_dataframe()
guru_profiles    = client.query(f'SELECT * FROM {dataset_id}.guru_profiles;').to_dataframe()

# %%
cm = sns.light_palette(COLORS[0], as_cmap=True)

linkedin_jobs.drop(['describtion', 'jobs_links', 'jobs_titles', 'skills']
                   , axis= 1).sample(5).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_d4294_row0_col9 {
#   background-color: #74facf;
#   color: #000000;
# }
# #T_d4294_row0_col10, #T_d4294_row1_col9, #T_d4294_row1_col10, #T_d4294_row2_col12, #T_d4294_row3_col9, #T_d4294_row4_col9, #T_d4294_row4_col10 {
#   background-color: #eaf3ef;
#   color: #000000;
# }
# #T_d4294_row0_col12, #T_d4294_row2_col10, #T_d4294_row4_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d4294_row1_col12, #T_d4294_row2_col9, #T_d4294_row3_col10 {
#   background-color: #51fcc6;
#   color: #000000;
# }
# #T_d4294_row3_col12 {
#   background-color: #d9f4ea;
#   color: #000000;
# }
# </style>
# <table id="T_d4294">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4294_level0_col0" class="col_heading level0 col0" >jobs_locations</th>
#       <th id="T_d4294_level0_col1" class="col_heading level0 col1" >listing_dates</th>
#       <th id="T_d4294_level0_col2" class="col_heading level0 col2" >companies_names</th>
#       <th id="T_d4294_level0_col3" class="col_heading level0 col3" >location_type</th>
#       <th id="T_d4294_level0_col4" class="col_heading level0 col4" >employment_type</th>
#       <th id="T_d4294_level0_col5" class="col_heading level0 col5" >industry</th>
#       <th id="T_d4294_level0_col6" class="col_heading level0 col6" >reqierd_credential</th>
#       <th id="T_d4294_level0_col7" class="col_heading level0 col7" >country</th>
#       <th id="T_d4294_level0_col8" class="col_heading level0 col8" >job_title</th>
#       <th id="T_d4294_level0_col9" class="col_heading level0 col9" >total_jobs</th>
#       <th id="T_d4294_level0_col10" class="col_heading level0 col10" >salary</th>
#       <th id="T_d4294_level0_col11" class="col_heading level0 col11" >programming_lang</th>
#       <th id="T_d4294_level0_col12" class="col_heading level0 col12" >exp_years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4294_level0_row0" class="row_heading level0 row0" >3176</th>
#       <td id="T_d4294_row0_col0" class="data row0 col0" >San Jose, CA</td>
#       <td id="T_d4294_row0_col1" class="data row0 col1" >2023-06-20</td>
#       <td id="T_d4294_row0_col2" class="data row0 col2" >Santa Clara Family Health Plan</td>
#       <td id="T_d4294_row0_col3" class="data row0 col3" >From office</td>
#       <td id="T_d4294_row0_col4" class="data row0 col4" >FULL_TIME</td>
#       <td id="T_d4294_row0_col5" class="data row0 col5" >Insurance</td>
#       <td id="T_d4294_row0_col6" class="data row0 col6" >bachelor degree</td>
#       <td id="T_d4294_row0_col7" class="data row0 col7" >European Union</td>
#       <td id="T_d4294_row0_col8" class="data row0 col8" >Data analyst</td>
#       <td id="T_d4294_row0_col9" class="data row0 col9" >156000</td>
#       <td id="T_d4294_row0_col10" class="data row0 col10" >100535.000000</td>
#       <td id="T_d4294_row0_col11" class="data row0 col11" >['scala' 'sql']</td>
#       <td id="T_d4294_row0_col12" class="data row0 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d4294_level0_row1" class="row_heading level0 row1" >2805</th>
#       <td id="T_d4294_row1_col0" class="data row1 col0" >Hayward, CA</td>
#       <td id="T_d4294_row1_col1" class="data row1 col1" >2023-02-01</td>
#       <td id="T_d4294_row1_col2" class="data row1 col2" >Recruiting from Scratch</td>
#       <td id="T_d4294_row1_col3" class="data row1 col3" >From office</td>
#       <td id="T_d4294_row1_col4" class="data row1 col4" >FULL_TIME</td>
#       <td id="T_d4294_row1_col5" class="data row1 col5" >Staffing and Recruiting</td>
#       <td id="T_d4294_row1_col6" class="data row1 col6" >bachelor degree</td>
#       <td id="T_d4294_row1_col7" class="data row1 col7" >European Union</td>
#       <td id="T_d4294_row1_col8" class="data row1 col8" >ML developer</td>
#       <td id="T_d4294_row1_col9" class="data row1 col9" >989</td>
#       <td id="T_d4294_row1_col10" class="data row1 col10" >205000.000000</td>
#       <td id="T_d4294_row1_col11" class="data row1 col11" >['scala' 'sql' 'c++']</td>
#       <td id="T_d4294_row1_col12" class="data row1 col12" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d4294_level0_row2" class="row_heading level0 row2" >1763</th>
#       <td id="T_d4294_row2_col0" class="data row2 col0" >Sunnyvale, CA</td>
#       <td id="T_d4294_row2_col1" class="data row2 col1" >2023-05-29</td>
#       <td id="T_d4294_row2_col2" class="data row2 col2" >Generis Tek Inc</td>
#       <td id="T_d4294_row2_col3" class="data row2 col3" >Remote</td>
#       <td id="T_d4294_row2_col4" class="data row2 col4" >CONTRACTOR</td>
#       <td id="T_d4294_row2_col5" class="data row2 col5" >IT Services and IT Consulting</td>
#       <td id="T_d4294_row2_col6" class="data row2 col6" >bachelor degree</td>
#       <td id="T_d4294_row2_col7" class="data row2 col7" >United States</td>
#       <td id="T_d4294_row2_col8" class="data row2 col8" >Data analyst</td>
#       <td id="T_d4294_row2_col9" class="data row2 col9" >202000</td>
#       <td id="T_d4294_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_d4294_row2_col11" class="data row2 col11" >['scala' 'java' 'c++' 'rust' 'sql' 'python']</td>
#       <td id="T_d4294_row2_col12" class="data row2 col12" >3.500000</td>
#     </tr>
#     <tr>
#       <th id="T_d4294_level0_row3" class="row_heading level0 row3" >717</th>
#       <td id="T_d4294_row3_col0" class="data row3 col0" >San Jose, CA</td>
#       <td id="T_d4294_row3_col1" class="data row3 col1" >2023-07-06</td>
#       <td id="T_d4294_row3_col2" class="data row3 col2" >Modular</td>
#       <td id="T_d4294_row3_col3" class="data row3 col3" >Hybrid</td>
#       <td id="T_d4294_row3_col4" class="data row3 col4" >FULL_TIME</td>
#       <td id="T_d4294_row3_col5" class="data row3 col5" >Technology, Information and Internet</td>
#       <td id="T_d4294_row3_col6" class="data row3 col6" >bachelor degree</td>
#       <td id="T_d4294_row3_col7" class="data row3 col7" >United States</td>
#       <td id="T_d4294_row3_col8" class="data row3 col8" >ML developer</td>
#       <td id="T_d4294_row3_col9" class="data row3 col9" >2000</td>
#       <td id="T_d4294_row3_col10" class="data row3 col10" >21650000.000000</td>
#       <td id="T_d4294_row3_col11" class="data row3 col11" >['scala' 'kotlin' 'c++' 'rust' 'python']</td>
#       <td id="T_d4294_row3_col12" class="data row3 col12" >3.666667</td>
#     </tr>
#     <tr>
#       <th id="T_d4294_level0_row4" class="row_heading level0 row4" >2912</th>
#       <td id="T_d4294_row4_col0" class="data row4 col0" >Menlo Park, CA</td>
#       <td id="T_d4294_row4_col1" class="data row4 col1" >2022-09-23</td>
#       <td id="T_d4294_row4_col2" class="data row4 col2" >Recruiting from Scratch</td>
#       <td id="T_d4294_row4_col3" class="data row4 col3" >Remote</td>
#       <td id="T_d4294_row4_col4" class="data row4 col4" >FULL_TIME</td>
#       <td id="T_d4294_row4_col5" class="data row4 col5" >Staffing and Recruiting</td>
#       <td id="T_d4294_row4_col6" class="data row4 col6" >bachelor degree</td>
#       <td id="T_d4294_row4_col7" class="data row4 col7" >United States</td>
#       <td id="T_d4294_row4_col8" class="data row4 col8" >ML developer</td>
#       <td id="T_d4294_row4_col9" class="data row4 col9" >2000</td>
#       <td id="T_d4294_row4_col10" class="data row4 col10" >182500.000000</td>
#       <td id="T_d4294_row4_col11" class="data row4 col11" >['scala' 'c++' 'python']</td>
#       <td id="T_d4294_row4_col12" class="data row4 col12" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette(COLORS[2], as_cmap=True)

upwork_profiles.drop(['describtion', 'skills']
                   , axis= 1).sample(5).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_a6aec_row0_col0, #T_a6aec_row1_col0, #T_a6aec_row2_col0, #T_a6aec_row2_col8, #T_a6aec_row3_col0, #T_a6aec_row3_col8, #T_a6aec_row3_col10, #T_a6aec_row4_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_a6aec_row0_col1 {
#   background-color: #84dbf6;
#   color: #000000;
# }
# #T_a6aec_row0_col8 {
#   background-color: #ceeaf3;
#   color: #000000;
# }
# #T_a6aec_row0_col9, #T_a6aec_row1_col9, #T_a6aec_row1_col10, #T_a6aec_row2_col1, #T_a6aec_row2_col9, #T_a6aec_row4_col1, #T_a6aec_row4_col8, #T_a6aec_row4_col10 {
#   background-color: #eef1f2;
#   color: #000000;
# }
# #T_a6aec_row0_col10, #T_a6aec_row1_col8, #T_a6aec_row3_col1, #T_a6aec_row3_col9 {
#   background-color: #5cd3f7;
#   color: #000000;
# }
# #T_a6aec_row1_col1 {
#   background-color: #b9e6f4;
#   color: #000000;
# }
# #T_a6aec_row2_col10 {
#   background-color: #97dff5;
#   color: #000000;
# }
# #T_a6aec_row4_col9 {
#   background-color: #74d8f6;
#   color: #000000;
# }
# </style>
# <table id="T_a6aec">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a6aec_level0_col0" class="col_heading level0 col0" >Unnamed__0</th>
#       <th id="T_a6aec_level0_col1" class="col_heading level0 col1" >feedback</th>
#       <th id="T_a6aec_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_a6aec_level0_col3" class="col_heading level0 col3" >job_title</th>
#       <th id="T_a6aec_level0_col4" class="col_heading level0 col4" >country</th>
#       <th id="T_a6aec_level0_col5" class="col_heading level0 col5" >consultations_offers</th>
#       <th id="T_a6aec_level0_col6" class="col_heading level0 col6" >data_job_title</th>
#       <th id="T_a6aec_level0_col7" class="col_heading level0 col7" >new_columns</th>
#       <th id="T_a6aec_level0_col8" class="col_heading level0 col8" >earnings_amount_new</th>
#       <th id="T_a6aec_level0_col9" class="col_heading level0 col9" >hour_rate_new</th>
#       <th id="T_a6aec_level0_col10" class="col_heading level0 col10" >exp_years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a6aec_level0_row0" class="row_heading level0 row0" >503</th>
#       <td id="T_a6aec_row0_col0" class="data row0 col0" ><NA></td>
#       <td id="T_a6aec_row0_col1" class="data row0 col1" >97.000000</td>
#       <td id="T_a6aec_row0_col2" class="data row0 col2" >Md Rakib H.</td>
#       <td id="T_a6aec_row0_col3" class="data row0 col3" >Data Entry, CRM Data Entry & Web Research Specialist</td>
#       <td id="T_a6aec_row0_col4" class="data row0 col4" >Bangladesh</td>
#       <td id="T_a6aec_row0_col5" class="data row0 col5" >Doesn't offer consultations</td>
#       <td id="T_a6aec_row0_col6" class="data row0 col6" >Data entry</td>
#       <td id="T_a6aec_row0_col7" class="data row0 col7" >{'earnings_amount_new': 9000, 'hour_rate_new': 4.99}</td>
#       <td id="T_a6aec_row0_col8" class="data row0 col8" >9000</td>
#       <td id="T_a6aec_row0_col9" class="data row0 col9" >4.990000</td>
#       <td id="T_a6aec_row0_col10" class="data row0 col10" >7.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6aec_level0_row1" class="row_heading level0 row1" >511</th>
#       <td id="T_a6aec_row1_col0" class="data row1 col0" ><NA></td>
#       <td id="T_a6aec_row1_col1" class="data row1 col1" >93.000000</td>
#       <td id="T_a6aec_row1_col2" class="data row1 col2" >Sadia M.</td>
#       <td id="T_a6aec_row1_col3" class="data row1 col3" >Online Researcher | Data Entry Specialist | Virtual Assistant</td>
#       <td id="T_a6aec_row1_col4" class="data row1 col4" >Pakistan</td>
#       <td id="T_a6aec_row1_col5" class="data row1 col5" >Doesn't offer consultations</td>
#       <td id="T_a6aec_row1_col6" class="data row1 col6" >Data entry</td>
#       <td id="T_a6aec_row1_col7" class="data row1 col7" >{'earnings_amount_new': 30000, 'hour_rate_new': 5.0}</td>
#       <td id="T_a6aec_row1_col8" class="data row1 col8" >30000</td>
#       <td id="T_a6aec_row1_col9" class="data row1 col9" >5.000000</td>
#       <td id="T_a6aec_row1_col10" class="data row1 col10" >2.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6aec_level0_row2" class="row_heading level0 row2" >376</th>
#       <td id="T_a6aec_row2_col0" class="data row2 col0" ><NA></td>
#       <td id="T_a6aec_row2_col1" class="data row2 col1" >89.000000</td>
#       <td id="T_a6aec_row2_col2" class="data row2 col2" >Tazmir H.</td>
#       <td id="T_a6aec_row2_col3" class="data row2 col3" >Lead Generator, Data Scraping, LinkedIn Premium, Data Mining/Entry.</td>
#       <td id="T_a6aec_row2_col4" class="data row2 col4" >Bangladesh</td>
#       <td id="T_a6aec_row2_col5" class="data row2 col5" >Doesn't offer consultations</td>
#       <td id="T_a6aec_row2_col6" class="data row2 col6" >Data entry</td>
#       <td id="T_a6aec_row2_col7" class="data row2 col7" >{'earnings_amount_new': None, 'hour_rate_new': 4.99}</td>
#       <td id="T_a6aec_row2_col8" class="data row2 col8" ><NA></td>
#       <td id="T_a6aec_row2_col9" class="data row2 col9" >4.990000</td>
#       <td id="T_a6aec_row2_col10" class="data row2 col10" >5.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a6aec_level0_row3" class="row_heading level0 row3" >47</th>
#       <td id="T_a6aec_row3_col0" class="data row3 col0" ><NA></td>
#       <td id="T_a6aec_row3_col1" class="data row3 col1" >100.000000</td>
#       <td id="T_a6aec_row3_col2" class="data row3 col2" >Khizar H.</td>
#       <td id="T_a6aec_row3_col3" class="data row3 col3" >Computer Vision | AI | Full Stack | NLP LLMs OpenAI | ML Data Science</td>
#       <td id="T_a6aec_row3_col4" class="data row3 col4" >Pakistan</td>
#       <td id="T_a6aec_row3_col5" class="data row3 col5" >Offers consultations</td>
#       <td id="T_a6aec_row3_col6" class="data row3 col6" >Machine Learning</td>
#       <td id="T_a6aec_row3_col7" class="data row3 col7" >{'earnings_amount_new': None, 'hour_rate_new': 35.0}</td>
#       <td id="T_a6aec_row3_col8" class="data row3 col8" ><NA></td>
#       <td id="T_a6aec_row3_col9" class="data row3 col9" >35.000000</td>
#       <td id="T_a6aec_row3_col10" class="data row3 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_a6aec_level0_row4" class="row_heading level0 row4" >222</th>
#       <td id="T_a6aec_row4_col0" class="data row4 col0" ><NA></td>
#       <td id="T_a6aec_row4_col1" class="data row4 col1" >89.000000</td>
#       <td id="T_a6aec_row4_col2" class="data row4 col2" >Jehangeer A.</td>
#       <td id="T_a6aec_row4_col3" class="data row4 col3" >Data Scientist | Statistics Graduate | R Developer (Shiny) | SQL</td>
#       <td id="T_a6aec_row4_col4" class="data row4 col4" >Pakistan</td>
#       <td id="T_a6aec_row4_col5" class="data row4 col5" >Offers consultations</td>
#       <td id="T_a6aec_row4_col6" class="data row4 col6" >Data scientist</td>
#       <td id="T_a6aec_row4_col7" class="data row4 col7" >{'earnings_amount_new': 3000, 'hour_rate_new': 30.0}</td>
#       <td id="T_a6aec_row4_col8" class="data row4 col8" >3000</td>
#       <td id="T_a6aec_row4_col9" class="data row4 col9" >30.000000</td>
#       <td id="T_a6aec_row4_col10" class="data row4 col10" >2.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette(COLORS[4], as_cmap=True)

guru_profiles.drop(['describtion', 'skills']
                   , axis= 1).sample(5).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_139f1_row0_col0, #T_139f1_row1_col0, #T_139f1_row2_col0, #T_139f1_row3_col0, #T_139f1_row4_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_139f1_row0_col4, #T_139f1_row0_col7, #T_139f1_row0_col9, #T_139f1_row1_col7, #T_139f1_row1_col9, #T_139f1_row2_col4, #T_139f1_row2_col7, #T_139f1_row2_col8, #T_139f1_row2_col9, #T_139f1_row3_col7, #T_139f1_row3_col9, #T_139f1_row4_col4, #T_139f1_row4_col7, #T_139f1_row4_col9 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_139f1_row0_col8 {
#   background-color: #98aff8;
#   color: #000000;
# }
# #T_139f1_row1_col4, #T_139f1_row1_col8 {
#   background-color: #517afc;
#   color: #f1f1f1;
# }
# #T_139f1_row3_col4 {
#   background-color: #d3dbf4;
#   color: #000000;
# }
# #T_139f1_row3_col8 {
#   background-color: #e6e9f3;
#   color: #000000;
# }
# #T_139f1_row4_col8 {
#   background-color: #cdd6f5;
#   color: #000000;
# }
# </style>
# <table id="T_139f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_139f1_level0_col0" class="col_heading level0 col0" >Unnamed__0</th>
#       <th id="T_139f1_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_139f1_level0_col2" class="col_heading level0 col2" >job_title</th>
#       <th id="T_139f1_level0_col3" class="col_heading level0 col3" >addresse</th>
#       <th id="T_139f1_level0_col4" class="col_heading level0 col4" >minimum_pay</th>
#       <th id="T_139f1_level0_col5" class="col_heading level0 col5" >data_job_title</th>
#       <th id="T_139f1_level0_col6" class="col_heading level0 col6" >new_columns</th>
#       <th id="T_139f1_level0_col7" class="col_heading level0 col7" >earnings_amount_new</th>
#       <th id="T_139f1_level0_col8" class="col_heading level0 col8" >hour_rate_new</th>
#       <th id="T_139f1_level0_col9" class="col_heading level0 col9" >feedback_new</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_139f1_level0_row0" class="row_heading level0 row0" >1020</th>
#       <td id="T_139f1_row0_col0" class="data row0 col0" ><NA></td>
#       <td id="T_139f1_row0_col1" class="data row0 col1" >Ismail Hossain Polas</td>
#       <td id="T_139f1_row0_col2" class="data row0 col2" >Machine Learning Projects</td>
#       <td id="T_139f1_row0_col3" class="data row0 col3" >Dhaka, Dhaka, Bangladesh</td>
#       <td id="T_139f1_row0_col4" class="data row0 col4" >25.000000</td>
#       <td id="T_139f1_row0_col5" class="data row0 col5" >Machine Learning</td>
#       <td id="T_139f1_row0_col6" class="data row0 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 30.0}</td>
#       <td id="T_139f1_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_139f1_row0_col8" class="data row0 col8" >30.000000</td>
#       <td id="T_139f1_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_139f1_level0_row1" class="row_heading level0 row1" >1886</th>
#       <td id="T_139f1_row1_col0" class="data row1 col0" ><NA></td>
#       <td id="T_139f1_row1_col1" class="data row1 col1" >Venkata Gundapu</td>
#       <td id="T_139f1_row1_col2" class="data row1 col2" >Cloud Solution Engineer and Data Analyst</td>
#       <td id="T_139f1_row1_col3" class="data row1 col3" >Hyderabad, Telangana, India</td>
#       <td id="T_139f1_row1_col4" class="data row1 col4" >300.000000</td>
#       <td id="T_139f1_row1_col5" class="data row1 col5" >Data Analyst</td>
#       <td id="T_139f1_row1_col6" class="data row1 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 50.0}</td>
#       <td id="T_139f1_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_139f1_row1_col8" class="data row1 col8" >50.000000</td>
#       <td id="T_139f1_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_139f1_level0_row2" class="row_heading level0 row2" >160</th>
#       <td id="T_139f1_row2_col0" class="data row2 col0" ><NA></td>
#       <td id="T_139f1_row2_col1" class="data row2 col1" >Nafees Satti</td>
#       <td id="T_139f1_row2_col2" class="data row2 col2" >Data Entry</td>
#       <td id="T_139f1_row2_col3" class="data row2 col3" >Rawalpindi, Punjab, Pakistan</td>
#       <td id="T_139f1_row2_col4" class="data row2 col4" >25.000000</td>
#       <td id="T_139f1_row2_col5" class="data row2 col5" >Data entry</td>
#       <td id="T_139f1_row2_col6" class="data row2 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 5.0}</td>
#       <td id="T_139f1_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_139f1_row2_col8" class="data row2 col8" >5.000000</td>
#       <td id="T_139f1_row2_col9" class="data row2 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_139f1_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_139f1_row3_col0" class="data row3 col0" ><NA></td>
#       <td id="T_139f1_row3_col1" class="data row3 col1" >Cibi Jacob</td>
#       <td id="T_139f1_row3_col2" class="data row3 col2" >Data entry services</td>
#       <td id="T_139f1_row3_col3" class="data row3 col3" >Kerala, Kerala, India</td>
#       <td id="T_139f1_row3_col4" class="data row3 col4" >75.000000</td>
#       <td id="T_139f1_row3_col5" class="data row3 col5" >Data entry</td>
#       <td id="T_139f1_row3_col6" class="data row3 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 8.0}</td>
#       <td id="T_139f1_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_139f1_row3_col8" class="data row3 col8" >8.000000</td>
#       <td id="T_139f1_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_139f1_level0_row4" class="row_heading level0 row4" >483</th>
#       <td id="T_139f1_row4_col0" class="data row4 col0" ><NA></td>
#       <td id="T_139f1_row4_col1" class="data row4 col1" >Akpofure E.</td>
#       <td id="T_139f1_row4_col2" class="data row4 col2" >Data Analyst</td>
#       <td id="T_139f1_row4_col3" class="data row4 col3" >Benin City, Edo, Nigeria</td>
#       <td id="T_139f1_row4_col4" class="data row4 col4" >25.000000</td>
#       <td id="T_139f1_row4_col5" class="data row4 col5" >Data Analyst</td>
#       <td id="T_139f1_row4_col6" class="data row4 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 15.0}</td>
#       <td id="T_139f1_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_139f1_row4_col8" class="data row4 col8" >15.000000</td>
#       <td id="T_139f1_row4_col9" class="data row4 col9" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Basic cleaning:**

# %%
def tucky_method(array: np.array, indecies= True) -> np.array:
    """
    This function works with any list-like numerical object
    (don't work with pandas series's) and returns the indexes
    of the found outliers in the array.
    
    :Params: Takes only the series.
    :Returns: S list of the outliers indexes.
    """
    
    Q3 = np.quantile(array, 0.75)
    Q1 = np.quantile(array, 0.25)
    IQR = Q3 - Q1
    
    upper_range = Q3 + (IQR * 1.5)
    lower_range = Q1 - (IQR * 1.5)
    
    outliers = [x for x in array if ((x < lower_range) | (x > upper_range))]
    print(f"Found {len(outliers)} outliers from {len(array)} length series!")
    
    return outliers

# %%
upwork_profiles.drop(['Unnamed__0', 'new_columns'], axis= 1, inplace= True)
guru_profiles.drop(['Unnamed__0', 'new_columns'], axis= 1, inplace= True)

linkedin_jobs.drop(['jobs_links'], axis= 1, inplace= True)

linkedin_jobs['salary'] = linkedin_jobs['salary'].where((linkedin_jobs.salary < 70) |
                                                        (linkedin_jobs.salary > 10_000) &
                                                        (linkedin_jobs.salary > 5))

per_hour_or_year_map = lambda salary: 'per year' if salary > 10_000 else 'per hour' if salary < 100 else np.nan
linkedin_jobs['per_hour_or_year'] = linkedin_jobs['salary'].apply(per_hour_or_year_map)

# %%
outliers = tucky_method(linkedin_jobs[linkedin_jobs['per_hour_or_year'] == 'per year']['salary'].to_numpy())
outliers_indexes = np.array(*np.where(np.isin(linkedin_jobs['salary'], outliers)))
linkedin_jobs = linkedin_jobs.drop(outliers_indexes)

# outliers = z_score(linkedin_jobs['salary'].to_numpy())
# outliers_indexes = np.array(*np.where(np.isin(base_videos['viewCount'], outliers)))
# temp_base_videos = base_videos.drop(outliers_indexes)
# Out:
# Found 77 outliers from 964 length series!

# %% [markdown]
# ## <center><strong><span style= 'color: #5cd3f7'>Visualizing</span> the data (part 1)

# %%
def add_bar_labels(x,y, ax, scaler= 0):
    for i in range(len(x)):
        ax.text(i, y[i] + scaler , '{:,}'.format(y[i]), ha = 'center')

# %%
fig, (ax1, ax2) = plt.subplots(nrows= 2)

countries = ['\'United States\'', '\'European Union\'']

colors_temp = [COLORS[0]] * 1
colors_temp += ['lightgrey'] * 5

for ax, country in zip([ax1, ax2], countries):
    
    data = query_pandas(f'''SELECT total_jobs,
                                 job_title,
                                 country
                           FROM linkedin_jobs
                           WHERE country = {country}
                           GROUP BY job_title
                           ORDER BY total_jobs DESC;''')
    
    ax.bar(x=      data['job_title'],
           height= data['total_jobs'],
           color=  colors_temp)
    
    ax.spines[['right', 'top']].set_visible(False)

    ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
    
    ax.set_title(f'Available Jobs per job title in the {country}', fontsize= FONT, pad= 19)
    ax.set_ylabel('Total jobs', fontsize= FONT * 3.5/5)
    
    if ax is ax1:
        add_bar_labels(data['job_title'], data['total_jobs'], ax, scaler= 15000)
        
    if ax is ax2:
        add_bar_labels(data['job_title'], data['total_jobs'], ax, scaler= 5000)

        
fig.tight_layout(h_pad=0.5, w_pad=5)
fig.set_size_inches(13, 12)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)

platforms   : list = ['guru', 'upwork']
labels      : list = ['Earned money', 'Didn\'t earn money']
colors_temp : list = [COLORS[1], 'lightgrey']
explode     : list = [0.2, 0.2]

for ax, platform in zip([ax1, ax2], platforms):
    # The first row in the queried table below contains the people who have earned money count
    data = query_pandas(f'''SELECT COUNT(*) AS total_profiles
                           FROM {platform}_profiles
                           WHERE earnings_amount_new > 0
                           
                           UNION ALL
                           
                           SELECT COUNT(*) AS total_profiles
                           FROM {platform}_profiles
                           WHERE earnings_amount_new IS NULL OR 
                                 earnings_amount_new = 0;''')


    # Plot the pie chart on the current axis
    # ax.pie(counts, labels=labels, autopct='%2.1f%%', pctdistance=0.85, labeldistance=1.2, colors= colors_temp)
    
    ax.pie(data['total_profiles'], labels=labels, autopct='%2.1f%%',
           pctdistance=0.85, labeldistance=1.2, colors=colors_temp,
           startangle=90)
    
    ax.set_title(f'How many people earned money in {platform.title()}', fontsize= FONT, pad= 50)
                 
    centre_circle = plt.Circle((0, 0), 0.75, fc='white')
    ax.add_artist(centre_circle)

fig.tight_layout(w_pad=7)
fig.set_size_inches(13, 10)
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

width = 0.27

data = query_pandas(f'''SELECT AVG(salary) AS avg_salary,
                               country,
                               job_title

                        FROM linkedin_jobs
                        WHERE salary > 100 
                        GROUP BY country, job_title
                        ORDER BY avg_salary DESC;''')

us_data = data[data['country'] == 'United States']
eu_data = data[data['country'] == 'European Union']

positions_us = range(len(us_data))
positions_eu = [pos + width for pos in positions_us]


ax.bar(positions_us, us_data['avg_salary'], width,
       align='center', label='United States',
       color= COLORS[2])

ax.bar(positions_eu, eu_data['avg_salary'], width,
       align='center', label='European Union',
       color= 'lightgrey')


ax.spines[['right', 'top']].set_visible(False)
ax.set_xticks([pos + width/2 for pos in positions_us])
ax.set_xticklabels(us_data['job_title'], ha='center')

ax.set_title(f'Median Salary per data job in the US and EU', fontsize= FONT, pad= 50)
ax.set_xlabel('Job Title',      fontsize= FONT * 3.5/5)
ax.set_ylabel('Average Salary', fontsize= FONT * 3.5/5)


ax.get_yaxis().set_major_formatter(
    matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

ax.legend(fontsize="14")
fig.set_size_inches(13, 6)
fig.tight_layout()
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2)

cmap      = ListedColormap(COLORS)
grey_cmap = ListedColormap(GREYS)

top_5_describtions = query_pandas('''SELECT describtion
                                     FROM upwork_profiles
                                     WHERE earnings_amount_new IS NOT NULL
                                     ORDER BY earnings_amount_new DESC
                                     LIMIT 5;''')['describtion'].str.cat(sep= ' ')

least_5_describtions = query_pandas('''SELECT describtion
                                       FROM upwork_profiles
                                       WHERE earnings_amount_new IS NOT NULL
                                       ORDER BY earnings_amount_new
                                       LIMIT 5;''')['describtion'].str.cat(sep= ' ')

wordcloud_ax1 = WordCloud(collocations= False, background_color= 'white',
                      max_font_size= 45, colormap= cmap).generate(top_5_describtions)


wordcloud_ax2 = WordCloud(collocations= False, background_color= 'white',
                      max_font_size= 45, colormap= grey_cmap).generate(least_5_describtions)

ax1.set_title(f'Top 5 Freelancers\'s \nDescribtions Most Frequent Words', fontsize= FONT, pad= 50)
ax2.set_title(f'Least 5 Freelancers\'s \nDescribtions Most Frequent', fontsize= FONT, pad= 50)

ax1.imshow(wordcloud_ax1, interpolation='bilinear')
ax1.axis("off")

ax2.imshow(wordcloud_ax2, interpolation='bilinear')
ax2.axis("off")

fig.set_size_inches(13, 6)
plt.tight_layout(w_pad= 5)
plt.show()

# %%
for proffesion in linkedin_jobs['job_title'].unique():
    
    np.unique(np.concatenate(linkedin_jobs[
        (linkedin_jobs['job_title'] == 'Data analyst') & 
        (linkedin_jobs['country']   == 'United States')].reset_index()['skills']),
              
             return_counts=True)

# %%
linkedin_jobs['job_title'].unique()
# Out:
# array(['Data analyst', 'ML developer', 'Data scientist', 'Data engineer',
#        'Data entry'], dtype=object)

# %%
skills_count = dict(Counter(np.concatenate(linkedin_jobs[
                    (linkedin_jobs['job_title'] == 'ML developer') & 
                    (linkedin_jobs['country']   == 'United States')].reset_index()['skills'])))

top_10_skills_count = {k: v for k, v in sorted(skills_count.items(), key=lambda item: item[1], reverse=True)[:10]}

# %%
sorted_skills_count
# Out:
# {'machine learning': 145,
#  'aws': 113,
#  'kubernetes': 84,
#  'excel': 75,
#  'attention to detail': 63,
#  'docker': 58,
#  'gcp': 52,
#  'computer vision': 43,
#  'spark': 40,
#  'pytorch': 38}
