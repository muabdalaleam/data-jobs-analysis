# %% [markdown]
# ## <center><strong>Notebook describtion & Our <span style= 'color: #51fcc6'>Questions</span>

# %% [markdown]
# In this notebook we are going to create the charts that we are going to use in the final pdf report and the tools we are going<br>
# to use are matplotlib and seaborn.

# %% [markdown]
# #### **Questions we are going to awnser:**
# 1. How many jobs are available per country and per profession on Likedin.
#
# 2. What's the ratio between people who earned money on UpWork Vs Guru.
#
# 3. Average salary per profession and per country on LinkedIn.
#
# 4. What's Top 5 people in earnings amount most frequent words in thier describtions.<sub> *(In upwork</sub>
#
# 5. What's Worst 5 people in earnings amount most frequent words in thier describtions.<sub> *(In upwork)</sub>
#
# 6. What are the most appending skills in the job titels per profession.<sub> *(In upwork & LinkedIn)</sub>
#
# 7. What are the Top 10 skills in earnings. <sub> *(In upwork & LinkedIn)</sub>
#
# 8. Correlation between Earnings amount, Years of Exp, Hour rate & Feedback in Upwork.
#
# 9. Does the Consultations offers affect the Earnings amount strongly.
#
# 10. Top 3 countries in total freelancers earnings Vs Top 3 countries in freelancers count <sub> *(In upwork & guru)</sub>
#
# 11. Jobs count per Jobs location per profession.
#
# 12. Where are the most job loactions in general per profession.
#
# 13. What's the average salary per proffision & per country.
#
# 14. What's the most common Employment type per data jobs in general.
#
# 15. Jobs count vs listing dates per proffision to see thier growth trends.
#
# 16. most common Earning abount, hour rate, exp years per proffision in Upwork.

# %% [markdown]
# #### **Important note:**
# I am going to use  **`pandasql`** to read the data from the dfs so I can create plots more easly using SQL<br>
# queries inside python.

# %% [markdown]
# ## <center><strong>Importing the <span style= 'color: #48e0dc'>Packeges

# %%
import os
import warnings
import matplotlib
import pandasql           as ps
import pandas             as pd
import numpy              as np
import seaborn            as sns
import matplotlib.pyplot  as plt

from google.cloud         import bigquery
from wordcloud            import WordCloud
from collections          import Counter

# %%
# %matplotlib inline
plt.rcParams['font.family'] = 'Candara'

warnings.filterwarnings('ignore')

credentials_path :str = '../credentials.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = credentials_path

FONT             :int  = 20
COLORS           :list = ['#51fcc6', '#48e0dc', '#5cd3f7', '#4895e0', '#517afc']
NUMERICS         :list = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64',
                          'uint16', 'uint32', 'uint64']

# %% [markdown]
# ## <center><strong>Loading the data & basic data <span style= 'color: #5cd3f7'>Cleaning

# %%
project_id :str = 'data-jobs-analysis-db'
dataset_id :str = 'data_jobs_analysis_db'

query_pandas  = lambda q: ps.sqldf(q, globals())
client        = bigquery.Client(project= project_id)

linkedin_jobs    = client.query(f'SELECT * FROM {dataset_id}.linkedin_jobs_new;').to_dataframe()
upwork_profiles  = client.query(f'SELECT * FROM {dataset_id}.upwork_profiles_new;').to_dataframe()
guru_profiles    = client.query(f'SELECT * FROM {dataset_id}.guru_profiles_new;').to_dataframe()

# %%
cm = sns.light_palette(COLORS[0], as_cmap=True)

linkedin_jobs.drop(['describtion', 'jobs_links', 'jobs_titles', 'skills']
                   , axis= 1).sample(5).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_d514b_row0_col9, #T_d514b_row0_col12 {
#   background-color: #51fcc6;
#   color: #000000;
# }
# #T_d514b_row0_col10, #T_d514b_row1_col10, #T_d514b_row2_col10, #T_d514b_row3_col9, #T_d514b_row3_col10, #T_d514b_row4_col10, #T_d514b_row4_col12 {
#   background-color: #eaf3ef;
#   color: #000000;
# }
# #T_d514b_row1_col9, #T_d514b_row2_col9 {
#   background-color: #e8f3ee;
#   color: #000000;
# }
# #T_d514b_row1_col12, #T_d514b_row2_col12, #T_d514b_row3_col12 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_d514b_row4_col9 {
#   background-color: #dff3ec;
#   color: #000000;
# }
# </style>
# <table id="T_d514b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d514b_level0_col0" class="col_heading level0 col0" >jobs_locations</th>
#       <th id="T_d514b_level0_col1" class="col_heading level0 col1" >listing_dates</th>
#       <th id="T_d514b_level0_col2" class="col_heading level0 col2" >companies_names</th>
#       <th id="T_d514b_level0_col3" class="col_heading level0 col3" >location_type</th>
#       <th id="T_d514b_level0_col4" class="col_heading level0 col4" >employment_type</th>
#       <th id="T_d514b_level0_col5" class="col_heading level0 col5" >industry</th>
#       <th id="T_d514b_level0_col6" class="col_heading level0 col6" >reqierd_credential</th>
#       <th id="T_d514b_level0_col7" class="col_heading level0 col7" >country</th>
#       <th id="T_d514b_level0_col8" class="col_heading level0 col8" >job_title</th>
#       <th id="T_d514b_level0_col9" class="col_heading level0 col9" >total_jobs</th>
#       <th id="T_d514b_level0_col10" class="col_heading level0 col10" >salary</th>
#       <th id="T_d514b_level0_col11" class="col_heading level0 col11" >programming_lang</th>
#       <th id="T_d514b_level0_col12" class="col_heading level0 col12" >exp_years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d514b_level0_row0" class="row_heading level0 row0" >1127</th>
#       <td id="T_d514b_row0_col0" class="data row0 col0" >Mountain View, CA</td>
#       <td id="T_d514b_row0_col1" class="data row0 col1" >2023-03-29</td>
#       <td id="T_d514b_row0_col2" class="data row0 col2" >CVPartners</td>
#       <td id="T_d514b_row0_col3" class="data row0 col3" >From office</td>
#       <td id="T_d514b_row0_col4" class="data row0 col4" >FULL_TIME</td>
#       <td id="T_d514b_row0_col5" class="data row0 col5" >Financial Services,Accounting</td>
#       <td id="T_d514b_row0_col6" class="data row0 col6" >associate degree</td>
#       <td id="T_d514b_row0_col7" class="data row0 col7" >United States</td>
#       <td id="T_d514b_row0_col8" class="data row0 col8" >Data entry</td>
#       <td id="T_d514b_row0_col9" class="data row0 col9" >786000</td>
#       <td id="T_d514b_row0_col10" class="data row0 col10" >nan</td>
#       <td id="T_d514b_row0_col11" class="data row0 col11" >[]</td>
#       <td id="T_d514b_row0_col12" class="data row0 col12" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d514b_level0_row1" class="row_heading level0 row1" >1305</th>
#       <td id="T_d514b_row1_col0" class="data row1 col0" >San Francisco, CA</td>
#       <td id="T_d514b_row1_col1" class="data row1 col1" >2023-06-09</td>
#       <td id="T_d514b_row1_col2" class="data row1 col2" >PlayStation</td>
#       <td id="T_d514b_row1_col3" class="data row1 col3" >Hybrid</td>
#       <td id="T_d514b_row1_col4" class="data row1 col4" >FULL_TIME</td>
#       <td id="T_d514b_row1_col5" class="data row1 col5" >Software Development,Consumer Services,Entertainment Providers</td>
#       <td id="T_d514b_row1_col6" class="data row1 col6" >bachelor degree</td>
#       <td id="T_d514b_row1_col7" class="data row1 col7" >United States</td>
#       <td id="T_d514b_row1_col8" class="data row1 col8" >Data scientist</td>
#       <td id="T_d514b_row1_col9" class="data row1 col9" >167000</td>
#       <td id="T_d514b_row1_col10" class="data row1 col10" >143300.000000</td>
#       <td id="T_d514b_row1_col11" class="data row1 col11" >['scala' 'java' 'python']</td>
#       <td id="T_d514b_row1_col12" class="data row1 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d514b_level0_row2" class="row_heading level0 row2" >906</th>
#       <td id="T_d514b_row2_col0" class="data row2 col0" >Mountain View, CA</td>
#       <td id="T_d514b_row2_col1" class="data row2 col1" >2023-03-30</td>
#       <td id="T_d514b_row2_col2" class="data row2 col2" >Matician</td>
#       <td id="T_d514b_row2_col3" class="data row2 col3" >Remote</td>
#       <td id="T_d514b_row2_col4" class="data row2 col4" >FULL_TIME</td>
#       <td id="T_d514b_row2_col5" class="data row2 col5" >Computers and Electronics Manufacturing</td>
#       <td id="T_d514b_row2_col6" class="data row2 col6" >bachelor degree</td>
#       <td id="T_d514b_row2_col7" class="data row2 col7" >United States</td>
#       <td id="T_d514b_row2_col8" class="data row2 col8" >Data scientist</td>
#       <td id="T_d514b_row2_col9" class="data row2 col9" >167000</td>
#       <td id="T_d514b_row2_col10" class="data row2 col10" >nan</td>
#       <td id="T_d514b_row2_col11" class="data row2 col11" >['rust' 'scala' 'c++' 'python']</td>
#       <td id="T_d514b_row2_col12" class="data row2 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d514b_level0_row3" class="row_heading level0 row3" >2454</th>
#       <td id="T_d514b_row3_col0" class="data row3 col0" >Santa Clara, CA</td>
#       <td id="T_d514b_row3_col1" class="data row3 col1" >2023-02-01</td>
#       <td id="T_d514b_row3_col2" class="data row3 col2" >Blue Ocean Ventures</td>
#       <td id="T_d514b_row3_col3" class="data row3 col3" >Remote</td>
#       <td id="T_d514b_row3_col4" class="data row3 col4" >CONTRACTOR</td>
#       <td id="T_d514b_row3_col5" class="data row3 col5" >Staffing and Recruiting</td>
#       <td id="T_d514b_row3_col6" class="data row3 col6" >bachelor degree</td>
#       <td id="T_d514b_row3_col7" class="data row3 col7" >European Union</td>
#       <td id="T_d514b_row3_col8" class="data row3 col8" >Data analyst</td>
#       <td id="T_d514b_row3_col9" class="data row3 col9" >156000</td>
#       <td id="T_d514b_row3_col10" class="data row3 col10" >nan</td>
#       <td id="T_d514b_row3_col11" class="data row3 col11" >['rust' 'sql']</td>
#       <td id="T_d514b_row3_col12" class="data row3 col12" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_d514b_level0_row4" class="row_heading level0 row4" >587</th>
#       <td id="T_d514b_row4_col0" class="data row4 col0" >Cupertino, CA</td>
#       <td id="T_d514b_row4_col1" class="data row4 col1" >2023-05-02</td>
#       <td id="T_d514b_row4_col2" class="data row4 col2" >WinMax</td>
#       <td id="T_d514b_row4_col3" class="data row4 col3" >Remote</td>
#       <td id="T_d514b_row4_col4" class="data row4 col4" >FULL_TIME</td>
#       <td id="T_d514b_row4_col5" class="data row4 col5" >IT Services and IT Consulting</td>
#       <td id="T_d514b_row4_col6" class="data row4 col6" >bachelor degree</td>
#       <td id="T_d514b_row4_col7" class="data row4 col7" >United States</td>
#       <td id="T_d514b_row4_col8" class="data row4 col8" >Data analyst</td>
#       <td id="T_d514b_row4_col9" class="data row4 col9" >202000</td>
#       <td id="T_d514b_row4_col10" class="data row4 col10" >nan</td>
#       <td id="T_d514b_row4_col11" class="data row4 col11" >['sql' 'scala' 'python' 'css']</td>
#       <td id="T_d514b_row4_col12" class="data row4 col12" >2.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette(COLORS[2], as_cmap=True)

upwork_profiles.drop(['describtion', 'skills']
                   , axis= 1).sample(5).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_14a60_row0_col0, #T_14a60_row0_col1, #T_14a60_row1_col0, #T_14a60_row1_col10, #T_14a60_row2_col0, #T_14a60_row2_col1, #T_14a60_row2_col10, #T_14a60_row3_col0, #T_14a60_row3_col1, #T_14a60_row3_col10, #T_14a60_row4_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_14a60_row0_col8 {
#   background-color: #b4e5f4;
#   color: #000000;
# }
# #T_14a60_row0_col9 {
#   background-color: #90def5;
#   color: #000000;
# }
# #T_14a60_row0_col10, #T_14a60_row1_col8, #T_14a60_row3_col9, #T_14a60_row4_col1 {
#   background-color: #5cd3f7;
#   color: #000000;
# }
# #T_14a60_row1_col1, #T_14a60_row1_col9, #T_14a60_row4_col8, #T_14a60_row4_col10 {
#   background-color: #eef1f2;
#   color: #000000;
# }
# #T_14a60_row2_col8 {
#   background-color: #e3eff3;
#   color: #000000;
# }
# #T_14a60_row2_col9 {
#   background-color: #bae6f4;
#   color: #000000;
# }
# #T_14a60_row3_col8 {
#   background-color: #ebf0f3;
#   color: #000000;
# }
# #T_14a60_row4_col9 {
#   background-color: #e5eff3;
#   color: #000000;
# }
# </style>
# <table id="T_14a60">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14a60_level0_col0" class="col_heading level0 col0" >Unnamed__0</th>
#       <th id="T_14a60_level0_col1" class="col_heading level0 col1" >feedback</th>
#       <th id="T_14a60_level0_col2" class="col_heading level0 col2" >name</th>
#       <th id="T_14a60_level0_col3" class="col_heading level0 col3" >job_title</th>
#       <th id="T_14a60_level0_col4" class="col_heading level0 col4" >country</th>
#       <th id="T_14a60_level0_col5" class="col_heading level0 col5" >consultations_offers</th>
#       <th id="T_14a60_level0_col6" class="col_heading level0 col6" >data_job_title</th>
#       <th id="T_14a60_level0_col7" class="col_heading level0 col7" >new_columns</th>
#       <th id="T_14a60_level0_col8" class="col_heading level0 col8" >earnings_amount_new</th>
#       <th id="T_14a60_level0_col9" class="col_heading level0 col9" >hour_rate_new</th>
#       <th id="T_14a60_level0_col10" class="col_heading level0 col10" >exp_years</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14a60_level0_row0" class="row_heading level0 row0" >352</th>
#       <td id="T_14a60_row0_col0" class="data row0 col0" ><NA></td>
#       <td id="T_14a60_row0_col1" class="data row0 col1" >nan</td>
#       <td id="T_14a60_row0_col2" class="data row0 col2" >Sourish B.</td>
#       <td id="T_14a60_row0_col3" class="data row0 col3" >Data Scientist | AI and ML Product Development Specialist</td>
#       <td id="T_14a60_row0_col4" class="data row0 col4" >United Kingdom</td>
#       <td id="T_14a60_row0_col5" class="data row0 col5" >Doesn't offer consultations</td>
#       <td id="T_14a60_row0_col6" class="data row0 col6" >Data scientist</td>
#       <td id="T_14a60_row0_col7" class="data row0 col7" >{'earnings_amount_new': 20000, 'hour_rate_new': 100.0}</td>
#       <td id="T_14a60_row0_col8" class="data row0 col8" >20000</td>
#       <td id="T_14a60_row0_col9" class="data row0 col9" >100.000000</td>
#       <td id="T_14a60_row0_col10" class="data row0 col10" >8.500000</td>
#     </tr>
#     <tr>
#       <th id="T_14a60_level0_row1" class="row_heading level0 row1" >516</th>
#       <td id="T_14a60_row1_col0" class="data row1 col0" ><NA></td>
#       <td id="T_14a60_row1_col1" class="data row1 col1" >98.000000</td>
#       <td id="T_14a60_row1_col2" class="data row1 col2" >Aimieren C.</td>
#       <td id="T_14a60_row1_col3" class="data row1 col3" >Image & Video Annotator/Labeller/Tagger/Data Labeling/CVAT Expert</td>
#       <td id="T_14a60_row1_col4" class="data row1 col4" >Philippines</td>
#       <td id="T_14a60_row1_col5" class="data row1 col5" >Doesn't offer consultations</td>
#       <td id="T_14a60_row1_col6" class="data row1 col6" >Machine Learning</td>
#       <td id="T_14a60_row1_col7" class="data row1 col7" >{'earnings_amount_new': 50000, 'hour_rate_new': 8.0}</td>
#       <td id="T_14a60_row1_col8" class="data row1 col8" >50000</td>
#       <td id="T_14a60_row1_col9" class="data row1 col9" >8.000000</td>
#       <td id="T_14a60_row1_col10" class="data row1 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_14a60_level0_row2" class="row_heading level0 row2" >702</th>
#       <td id="T_14a60_row2_col0" class="data row2 col0" ><NA></td>
#       <td id="T_14a60_row2_col1" class="data row2 col1" >nan</td>
#       <td id="T_14a60_row2_col2" class="data row2 col2" >Oleg M.</td>
#       <td id="T_14a60_row2_col3" class="data row2 col3" >Financial modeling expert, data scientist</td>
#       <td id="T_14a60_row2_col4" class="data row2 col4" >Ukraine</td>
#       <td id="T_14a60_row2_col5" class="data row2 col5" >Doesn't offer consultations</td>
#       <td id="T_14a60_row2_col6" class="data row2 col6" >Data scientist</td>
#       <td id="T_14a60_row2_col7" class="data row2 col7" >{'earnings_amount_new': 4000, 'hour_rate_new': 59.0}</td>
#       <td id="T_14a60_row2_col8" class="data row2 col8" >4000</td>
#       <td id="T_14a60_row2_col9" class="data row2 col9" >59.000000</td>
#       <td id="T_14a60_row2_col10" class="data row2 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_14a60_level0_row3" class="row_heading level0 row3" >936</th>
#       <td id="T_14a60_row3_col0" class="data row3 col0" ><NA></td>
#       <td id="T_14a60_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_14a60_row3_col2" class="data row3 col2" >Nisar Ahmad H.</td>
#       <td id="T_14a60_row3_col3" class="data row3 col3" >PhD AI & ML, US Patent, 15 years Data Science, NLU, Computer Vision VR</td>
#       <td id="T_14a60_row3_col4" class="data row3 col4" >United States</td>
#       <td id="T_14a60_row3_col5" class="data row3 col5" >Doesn't offer consultations</td>
#       <td id="T_14a60_row3_col6" class="data row3 col6" >Data Engineering</td>
#       <td id="T_14a60_row3_col7" class="data row3 col7" >{'earnings_amount_new': 1000, 'hour_rate_new': 150.0}</td>
#       <td id="T_14a60_row3_col8" class="data row3 col8" >1000</td>
#       <td id="T_14a60_row3_col9" class="data row3 col9" >150.000000</td>
#       <td id="T_14a60_row3_col10" class="data row3 col10" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_14a60_level0_row4" class="row_heading level0 row4" >191</th>
#       <td id="T_14a60_row4_col0" class="data row4 col0" ><NA></td>
#       <td id="T_14a60_row4_col1" class="data row4 col1" >99.000000</td>
#       <td id="T_14a60_row4_col2" class="data row4 col2" >Farhan H.</td>
#       <td id="T_14a60_row4_col3" class="data row4 col3" >Excel Expert | Data Analyst | Google Sheets Expert</td>
#       <td id="T_14a60_row4_col4" class="data row4 col4" >Pakistan</td>
#       <td id="T_14a60_row4_col5" class="data row4 col5" >Offers consultations</td>
#       <td id="T_14a60_row4_col6" class="data row4 col6" >Data Engineering</td>
#       <td id="T_14a60_row4_col7" class="data row4 col7" >{'earnings_amount_new': 10, 'hour_rate_new': 17.0}</td>
#       <td id="T_14a60_row4_col8" class="data row4 col8" >10</td>
#       <td id="T_14a60_row4_col9" class="data row4 col9" >17.000000</td>
#       <td id="T_14a60_row4_col10" class="data row4 col10" >6.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
cm = sns.light_palette(COLORS[4], as_cmap=True)

guru_profiles.drop(['describtion', 'skills']
                   , axis= 1).sample(5).style.background_gradient(cmap= cm)
# Out:
# <style type="text/css">
# #T_1e318_row0_col0, #T_1e318_row1_col0, #T_1e318_row2_col0, #T_1e318_row3_col0, #T_1e318_row4_col0 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_1e318_row0_col4, #T_1e318_row0_col7, #T_1e318_row0_col9, #T_1e318_row1_col7, #T_1e318_row1_col9, #T_1e318_row2_col7, #T_1e318_row2_col9, #T_1e318_row3_col4, #T_1e318_row3_col7, #T_1e318_row3_col8, #T_1e318_row3_col9, #T_1e318_row4_col4, #T_1e318_row4_col7, #T_1e318_row4_col9 {
#   background-color: #f0f0f3;
#   color: #000000;
# }
# #T_1e318_row0_col8 {
#   background-color: #e3e7f3;
#   color: #000000;
# }
# #T_1e318_row1_col4, #T_1e318_row1_col8 {
#   background-color: #517afc;
#   color: #f1f1f1;
# }
# #T_1e318_row2_col4 {
#   background-color: #e6e9f3;
#   color: #000000;
# }
# #T_1e318_row2_col8 {
#   background-color: #edeef3;
#   color: #000000;
# }
# #T_1e318_row4_col8 {
#   background-color: #ebedf3;
#   color: #000000;
# }
# </style>
# <table id="T_1e318">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e318_level0_col0" class="col_heading level0 col0" >Unnamed__0</th>
#       <th id="T_1e318_level0_col1" class="col_heading level0 col1" >name</th>
#       <th id="T_1e318_level0_col2" class="col_heading level0 col2" >job_title</th>
#       <th id="T_1e318_level0_col3" class="col_heading level0 col3" >addresse</th>
#       <th id="T_1e318_level0_col4" class="col_heading level0 col4" >minimum_pay</th>
#       <th id="T_1e318_level0_col5" class="col_heading level0 col5" >data_job_title</th>
#       <th id="T_1e318_level0_col6" class="col_heading level0 col6" >new_columns</th>
#       <th id="T_1e318_level0_col7" class="col_heading level0 col7" >earnings_amount_new</th>
#       <th id="T_1e318_level0_col8" class="col_heading level0 col8" >hour_rate_new</th>
#       <th id="T_1e318_level0_col9" class="col_heading level0 col9" >feedback_new</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e318_level0_row0" class="row_heading level0 row0" >511</th>
#       <td id="T_1e318_row0_col0" class="data row0 col0" ><NA></td>
#       <td id="T_1e318_row0_col1" class="data row0 col1" >Rahul_Kumawat</td>
#       <td id="T_1e318_row0_col2" class="data row0 col2" >Content Writing & Data Analyst</td>
#       <td id="T_1e318_row0_col3" class="data row0 col3" >Jaipur, Rajasthan, India</td>
#       <td id="T_1e318_row0_col4" class="data row0 col4" >25.000000</td>
#       <td id="T_1e318_row0_col5" class="data row0 col5" >Data Analyst</td>
#       <td id="T_1e318_row0_col6" class="data row0 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 1525.0}</td>
#       <td id="T_1e318_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_1e318_row0_col8" class="data row0 col8" >1525.000000</td>
#       <td id="T_1e318_row0_col9" class="data row0 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1e318_level0_row1" class="row_heading level0 row1" >1548</th>
#       <td id="T_1e318_row1_col0" class="data row1 col0" ><NA></td>
#       <td id="T_1e318_row1_col1" class="data row1 col1" >Ernest Alfred</td>
#       <td id="T_1e318_row1_col2" class="data row1 col2" >Professional Data Entry Clerk</td>
#       <td id="T_1e318_row1_col3" class="data row1 col3" >Kumasi, Ashanti, Ghana</td>
#       <td id="T_1e318_row1_col4" class="data row1 col4" >100.000000</td>
#       <td id="T_1e318_row1_col5" class="data row1 col5" >Data entry</td>
#       <td id="T_1e318_row1_col6" class="data row1 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 10100.0}</td>
#       <td id="T_1e318_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_1e318_row1_col8" class="data row1 col8" >10100.000000</td>
#       <td id="T_1e318_row1_col9" class="data row1 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1e318_level0_row2" class="row_heading level0 row2" >1100</th>
#       <td id="T_1e318_row2_col0" class="data row2 col0" ><NA></td>
#       <td id="T_1e318_row2_col1" class="data row2 col1" >basma elsayed mohamed</td>
#       <td id="T_1e318_row2_col2" class="data row2 col2" >Data Entry</td>
#       <td id="T_1e318_row2_col3" class="data row2 col3" >Alexandria, Al Iskandariyah, Egypt</td>
#       <td id="T_1e318_row2_col4" class="data row2 col4" >30.000000</td>
#       <td id="T_1e318_row2_col5" class="data row2 col5" >Data entry</td>
#       <td id="T_1e318_row2_col6" class="data row2 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 930.0}</td>
#       <td id="T_1e318_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_1e318_row2_col8" class="data row2 col8" >930.000000</td>
#       <td id="T_1e318_row2_col9" class="data row2 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1e318_level0_row3" class="row_heading level0 row3" >208</th>
#       <td id="T_1e318_row3_col0" class="data row3 col0" ><NA></td>
#       <td id="T_1e318_row3_col1" class="data row3 col1" >Aamir942</td>
#       <td id="T_1e318_row3_col2" class="data row3 col2" >Data Entry</td>
#       <td id="T_1e318_row3_col3" class="data row3 col3" >Multan, Punjab, Pakistan</td>
#       <td id="T_1e318_row3_col4" class="data row3 col4" >25.000000</td>
#       <td id="T_1e318_row3_col5" class="data row3 col5" >Data entry</td>
#       <td id="T_1e318_row3_col6" class="data row3 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 725.0}</td>
#       <td id="T_1e318_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_1e318_row3_col8" class="data row3 col8" >725.000000</td>
#       <td id="T_1e318_row3_col9" class="data row3 col9" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_1e318_level0_row4" class="row_heading level0 row4" >327</th>
#       <td id="T_1e318_row4_col0" class="data row4 col0" ><NA></td>
#       <td id="T_1e318_row4_col1" class="data row4 col1" >Kiran Kumar Madanu</td>
#       <td id="T_1e318_row4_col2" class="data row4 col2" >Senior Data Analyst</td>
#       <td id="T_1e318_row4_col3" class="data row4 col3" >Hyderabad, Telangana, India</td>
#       <td id="T_1e318_row4_col4" class="data row4 col4" >25.000000</td>
#       <td id="T_1e318_row4_col5" class="data row4 col5" >Data Analyst</td>
#       <td id="T_1e318_row4_col6" class="data row4 col6" >{'earnings_amount_new': 0, 'feedback_new': 0.0, 'hour_rate_new': 1025.0}</td>
#       <td id="T_1e318_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_1e318_row4_col8" class="data row4 col8" >1025.000000</td>
#       <td id="T_1e318_row4_col9" class="data row4 col9" >0.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### **Basic cleaning:**

# %%
upwork_profiles.drop(['Unnamed__0', 'new_columns'], axis= 1, inplace= True)
guru_profiles.drop(['Unnamed__0', 'new_columns'], axis= 1, inplace= True)

linkedin_jobs.drop(['jobs_links'], axis= 1, inplace= True)

linkedin_jobs['salary'] = linkedin_jobs['salary'].where((linkedin_jobs.salary < 70) |
                                                        (linkedin_jobs.salary > 10_000) &
                                                        (linkedin_jobs.salary > 5))

per_hour_or_year_map = lambda salary: 'per year' if salary > 10_000 else 'per hour' if salary < 100 else np.nan
linkedin_jobs['per_hour_or_year'] = linkedin_jobs['salary'].apply(per_hour_or_year_map)


upwork_profiles['earnings_amount_new'] =

# %% [markdown]
# ## <center><strong><span style= 'color: #5cd3f7'>Visualizing</span> the data (part 1)

# %%
def add_bar_labels(x,y, ax, scaler= 0):
    for i in range(len(x)):
        ax.text(i, y[i] + scaler , '{:,}'.format(y[i]), ha = 'center')

# %%
fig, (ax1, ax2) = plt.subplots(nrows= 2)

countries = ['\'United States\'', '\'European Union\'']

colors_temp = [COLORS[2]] * 1
colors_temp += ['lightgrey'] * 5

for ax, country in zip([ax1, ax2], countries):
    
    data = query_pandas(f'''SELECT total_jobs,
                                 job_title,
                                 country
                           FROM linkedin_jobs
                           WHERE country = {country}
                           GROUP BY job_title
                           ORDER BY total_jobs DESC;''')
    
    ax.bar(x=      data['job_title'],
           height= data['total_jobs'],
           color=  colors_temp)
    
    ax.spines[['right', 'top']].set_visible(False)

    ax.get_yaxis().set_major_formatter(
        matplotlib.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
    
    ax.set_title(f'Available Jobs per job title in the {country}', fontsize= FONT, pad= 19)
    ax.set_ylabel('Total jobs', fontsize= FONT * 3.5/5)
    
    if ax is ax1:
        add_bar_labels(data['job_title'], data['total_jobs'], ax, scaler= 15000)
        
    if ax is ax2:
        add_bar_labels(data['job_title'], data['total_jobs'], ax, scaler= 5000)

        
fig.tight_layout(h_pad=0.5, w_pad=5)
fig.set_size_inches(13, 12)
plt.show()

# %%
# The second row in the queried table below contains the people who have earned money count
query_pandas('''SELECT COUNT(*) AS total_profiles
                FROM upwork_profiles
                WHERE earnings_amount_new > 0
                
                UNION
                
                SELECT COUNT(*) AS total_profiles
                FROM upwork_profiles
                WHERE earnings_amount_new IS NULL''')
# Out:
#    total_profiles
# 0             159
# 1             791
