# %% [markdown]
# # Introduction

# %% [markdown]
# Bla bla bla

# %% [markdown]
# # Setting up

# %%
import sqlite3
import duckdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

DB_URI = "file:./data/clean_database.db?mode=ro"

# %%
with sqlite3.connect(DB_URI, uri=True) as con:
    linkedin_df = pd.read_sql_query("SELECT * FROM linkedin", con)
    upwork_df   = pd.read_sql_query("SELECT * FROM upwork", con)
    guru_df     = pd.read_sql_query("SELECT * FROM guru", con)

# %% [markdown]
# # Analysis

# %%
data = duckdb.sql("""
    SELECT 
        COUNT(id),
        SUM(CASE WHEN pay_type IS NULL THEN 1 ELSE 0 END) AS null,
        SUM(CASE WHEN pay_type = 'Annually' THEN 1 ELSE 0 END) AS salaries,
        SUM(CASE WHEN pay_type = 'Hourly' THEN 1 ELSE 0 END) AS hourly,
        -- searched_country,
        searched_job_title
    FROM linkedin_df
    WHERE searched_country = 'United States'
    GROUP BY searched_job_title -- searched_country
    ORDER BY searched_job_title -- searched_country
    """).df()

fig, ax = plt.subplots()

width = 0.7
bottom = np.zeros(5)

ax.bar(data["searched_job_title"], data["null"],
       width, bottom=bottom,
       label="Not mentioned", color="darkgrey")
bottom += data["null"]

ax.bar(data["searched_job_title"], data["salaries"],
       width, bottom=bottom,
       label="Annually", color= "green")
bottom += data["salaries"]

ax.bar(data["searched_job_title"], data["hourly"],
       width,bottom=bottom,
       label="Hourly", color="lightgreen")

ax.set_title("Pay types in data-field jobs' descriptions\n In the U.S.A")
ax.legend(loc="lower right")

ax.spines[['right', 'top']].set_visible(False)
ax.set_ylabel("Jobs occurrences")

fig.set_size_inches(10, 5)

plt.show()

# %%
data
# Out:
#    count(id)  null  salaries  hourly searched_job_title
# 0        100  71.0      19.0    10.0       Data analyst
# 1         98  53.0      42.0     3.0      Data engineer
# 2         99  52.0       1.0    46.0         Data entry
# 3        100  56.0      42.0     2.0     Data scientist
# 4        100  58.0      27.0    15.0   Machine learning

# %%
duckdb.sql("""
    SELECT 
        COUNT(id) AS count,
        MEDIAN(salary_min) AS salary,
        searched_country,
        searched_job_title
    FROM linkedin_df
    WHERE salary_min IS NOT NULL AND
        pay_type = 'Annually'
    GROUP BY searched_country, searched_job_title
    HAVING count > 10
""").df()
# Out:
#    count    salary searched_country searched_job_title
# 0     19   95000.0    United States       Data analyst
# 1     27  135000.0    United States   Machine learning
# 2     42  104000.0    United States      Data engineer
# 3     42  140000.0    United States     Data scientist
