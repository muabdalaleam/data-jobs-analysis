# %% [markdown]
# # Introduction

# %% [markdown]
# This analysis is splitted into two major parts:
# - Analysis for the data field jobs via LinkedIn
# - Analysis for the data field freelancing market via Guru & UpWork
